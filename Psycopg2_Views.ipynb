# %% [markdown]
# # `Python to Postgresql (Psycopg2)`:
# # `Create/Use (VIEWS)` | `Bonus: Date-Time Queries`
#
# **<font color=red>Mr Fugu Data Science</font>**
#
#
# # (◕‿◕✿)
#
# [Github](https://github.com/MrFuguDataScience) | [Youtube](https://www.youtube.com/channel/UCbni-TDI-Ub8VlGaP8HLTNw?view_as=subscriber)
#
# `------------------`
#
# `Purpose & Outcome`:
#
# + Describe pursose and uses of `views`
# + Create 2 View examples
#    + Query Date Information

# %% [markdown]
# + If you are working in a real world scenario, you will most likely need to hide your credentials,   permissions, login & password
# that is where these files shine.
#
# [create init and config files](https://towardsdatascience.com/python-and-postgresql-how-to-access-a-postgresql-database-like-a-data-scientist-b5a9c5a0ea43) | [Python_configparser doc](https://docs.python.org/3/library/configparser.html) | [Postgres_tutorial_Python_PSQL](https://www.postgresqltutorial.com/postgresql-python/connect/)
#
# 1<sup>st</sup>) : create the initialization file:
#
# + use your terminal or notepad, unless your favorite editor directly converts to this format `.ini` file.
#     + on `Mac` I did `touch database_file_init.ini`
#         + `vi database_file.ini`     *then inside the file type following lines:*
#             + `[postgresql]`
#             + `host=localhost`
#             + `database=what_databse_you_want_to_access`
#             + `user= some_user_you_created_for_this_user_in_psql`
#             + `password= some_password_you_have_to_this_db`
#
# `------------------------------------------------`
#
# 2<sup>nd</sup>) : now the `config.py` file this will be used to take data from `init file` and outputs a `dictionary`.
#
# + this file will look like this as an **example**:
# `{‘host’: ‘localhost’, ‘database’: ‘suppliers’, ‘user’: ‘postgres’, ‘password’: ‘postgres’}` when it is read.
#
# `HERE IS THE CODE`:
#
# `____________________________________________________`
#
# #!/usr/bin/python    (can also do virtenv,env)
#
# from configparser import ConfigParser
#
# def config(filename='database.ini', section='postgresql'):
#     # create a parser
#     parser = ConfigParser()
#     # read config file
#     parser.read(filename)
#
#     # get section, default to postgresql
#     db = {}
#
#     # Checks to see if section (postgresql) parser exists
#     if parser.has_section(section):
#         params = parser.items(section)
#         for param in params:
#             db[param[0]] = param[1]
#
#     # Returns an error if a parameter is called that is not listed in the initialization file
#     else:
#         raise Exception('Section {0} not found in the {1} file'.format(section, filename))
#
#     return db
#
#
# **This code was adpated from online material on Postgres website and used in 1<sup>st</sup> & 3<sup>rd</sup> link above**
#
#
# `---------------------------------------`
#
# # Install Psycopg2:
#
# + `python -m pip install psycopg2`
#
# * if this doesn't work, try changing `pip` to `pip3` depending on what version of Python you are using
#
# + if that doesn't work either try to do: `conda install -c anaconda psycopg2`
#
#
# **For my installation I found problems with installation: I did two steps**: `pip3 install psycopg2` followed by the `conda install -c anaconda psycopg2`. The first install showed complete but did not work, I feel that I may have been imcomplete with all the dependencies needed. Also, I was getting a `Python 2.7 error hashing`. `I suggest that you first check the version of Python and Location PATH. I feel that my default Location may be anaconda calling Python if I remember correctly.`
#
# + I thought this was from using a wrong default version of Python, changed my default and still didn't work. That was not the entire case, try the above and hope this works for you.
#
# + Separate source for installing: depending on situation. [install on Mac](https://www.youtube.com/watch?v=N4RxnQH2pVY)
#
# `____________________________________________`

# %% [markdown]
# If you do not want to create init or config files: do something similar to this
#
# **`import psycopg2`**
#
# **`conn = psycopg2.connect("dbname=test, user=postgres")`** #Connect to an existing database
#
# **`cur = conn.cursor( )`** #Open a cursor to perform database operations`
#
#
# `--------------------------------------------`

# %%
import psycopg2             # python->psql connection
# 
import pandas as pd         # create dataframes 
# import calendar             # convert int to month
# import matplotlib.pyplot as plt  # barchar plot
import seaborn as sns

# Import the 'config' function from the config_user_dta.py file:
from config_user_dta import config

# %%
# Get the config params
params_ = config()

# Connect to the Postgres_DB:
conn = psycopg2.connect(**params_)

# Create new_cursor allowing us to write Python to execute PSQL:
cur = conn.cursor()

conn.autocommit = True  # read documentation understanding when to Use & NOT use (TRUE)

# %%
sql_="SELECT * FROM  ppl_cpu_purchases LIMIT 2"
cur.execute(sql_)
cur.fetchall()

# pd.DataFrame(cur.fetchall(),columns=['credit_card','email','first_name','last_name',
# 'primary_phone','cpu','purchase_date'])
# Out:
# [('5399-3484-4724-7187',
#   'gso@qiegan.sqe',
#   'Donyell Ann',
#   'Ospina',
#   '5219459148',
#   'Intel Core i1-7554K',
#   datetime.date(2019, 10, 31)),
#  ('1630-5261-6108-7631',
#   'xnji@gfruaxqnvm.fha',
#   'Bishop',
#   'Siyed',
#   '4164254716',
#   'AMD Ryzen 1 5827X',
#   datetime.date(2017, 7, 16))]

# %% [markdown]
# # What is a `View`?
#
# + It can be thought of as a 'psuedo-table'. It is not a real table but instead, a database object that stores a query.
#     + More or less, think of a `View` as a representation of your data and does not store anything unless you are using a `materialzed view`.
#     + Materialized views: are very fast lookups and often used in data-warehousing.
#
# + The view, can be used for subsetting data, joining multiple tables, even granting permissions are an option.
#
# + **General Setup**:
#
#
# `CREATE OR REPLACE view_name
# AS
# your_query`
#
# OR
#
# `CREATE [ OR REPLACE ] [ TEMP | TEMPORARY ] VIEW name [ ( column_name [, ...] ) ]
#     [ WITH ( view_option_name [= view_option_value] [, ... ] ) ]
#     AS query`
#
#
# # When Would I Use a `View`?
#
# + Consider if you are forming complex queries, running specific queries often or you may need to use those results for some other work you are doing. Then a `View` is a great option.
#
# + Why: Because, you can call the VIEW directly, because it has already stored your complex query and you can do further queries or processing if needed.
#
# `----------------------------------------------------`

# %% [markdown]
# # EX.1) Create View
#
# + Your Supervisor wants you to create a new table showing first,last name with credit card number and the cpu with purchase date.
#     + You have 2 tables you need to put together (via `inner join`)
# + You are accessing these data often and would benefit from creating a view.

# %%
sql_view=" CREATE VIEW customer_cpu_sales AS \
SELECT staging_fake_ppl.first_name || ' ' || staging_fake_ppl.last_name \
AS full_name, staging_fake_ppl.credit_card AS card,\
staging_fake_cpu_purchases.cpu,staging_fake_cpu_purchases.purchase_date \
 FROM staging_fake_cpu_purchases INNER JOIN staging_fake_ppl ON \
 staging_fake_ppl.credit_card=staging_fake_cpu_purchases.credit_card"

cur.execute(sql_view)

# %%
# QUERY OUR first VIEW:

s="SELECT * FROM customer_cpu_sales LIMIT 4"
cur.execute(s)
cur.fetchall()
# Out:
# [('Nasreen Angel',
#   '1000-1293-3496-7245',
#   'AMD Ryzen 4 6221X',
#   datetime.date(2018, 5, 27)),
#  ('Qirsten el-Azimi',
#   '1000-7698-8868-7669',
#   'Intel Core i5-2492K',
#   datetime.date(2020, 3, 9)),
#  ('Alejandro Batchelor',
#   '1002-7633-3301-5737',
#   'Intel Core i2-7948K',
#   datetime.date(2017, 10, 16)),
#  ('Gabriel Salazar',
#   '1003-1072-2532-5536',
#   'AMD Ryzen 5 5684X',
#   datetime.date(2020, 5, 23))]

# %%
# Update View: for example change the (name of our VIEW)

"ALTER VIEW customer_master RENAME TO customer_info"

# %%
# Delete View:

"DROP VIEW thne_your_viewName"

# %% [markdown]
# # Query and print days since purchase

# %%
sales_byDate="select date_trunc('day',now() - purchase_date::date) from customer_cpu_sales"
cur.execute(w)
cur.fetchone()
# Out:
# (datetime.timedelta(days=240),)

# %% [markdown]
# # Ex. 2) `View 02` Storing dates since Purchase
#
# + Now, you are asked to store the days elapsed since purchase tracked from today

# %%
cust_warr_view="CREATE VIEW customer_warranty AS SELECT *,\
date_trunc('day',now() - purchase_date::date) \
AS 'days_since_purchase' FROM ppl_cpu_purchases"
cur.execute(cust_warr_view)
# cur.fetchall()

# %%
sqq="select * from customer_warranty limit 2"
cur.execute(sqq)
cur.fetchall()
# Out:
# [('5399-3484-4724-7187',
#   'gso@qiegan.sqe',
#   'Donyell Ann',
#   'Ospina',
#   '5219459148',
#   'Intel Core i1-7554K',
#   datetime.date(2019, 10, 31),
#   datetime.timedelta(days=241)),
#  ('1630-5261-6108-7631',
#   'xnji@gfruaxqnvm.fha',
#   'Bishop',
#   'Siyed',
#   '4164254716',
#   'AMD Ryzen 1 5827X',
#   datetime.date(2017, 7, 16),
#   datetime.timedelta(days=1078))]

# %% [markdown]
# # Date-Time Queries:
#
# + Use `Extract function` with `CASE WHEN`
#
# * **Question**: Assume you have to track the age of your customer purchases for warranty information. `Imagine that you only have a warranty of (6 months: AKA 180 days)`.

# %%
xc="SELECT * FROM customer_warranty where extract(days from warranty) < 180 limit 3"

cur.execute(xc)
# cur.fetchall()

pd.DataFrame(cur.fetchall(),columns=['credit_card','email','first_name','last_name',
'primary_phone', 'cpu','purchase_date','days_since_purchase'])
# Out:
#            credit_card                 email first_name last_name  \
# 0  7536-4552-2504-7339     ybt@ehlczprdt.lbd    Everett     Vigil
# 1  2487-1704-2828-6891    urszdy@iplejhf.dwl      Paige    Burton
# 2  8464-3306-8207-9275  pvjderban@alfcbr.dax        Ann     Reish
#
#   primary_phone                  cpu purchase_date days_since_purchase
# 0    9722173416  Intel Core i3-2155K    2020-03-07            113 days
# 1    2178936729    AMD Ryzen 4 2978X    2020-04-09             80 days
# 2    5236872168    AMD Ryzen 4 5508X    2020-04-26             63 days

# %% [markdown]
# # Not All Queries Go AS PLANNED:

# %%
dates_n_warr="SELECT *,\
date_trunc('day',now() - purchase_date::date) \
AS days_since_purchase, \
CASE WHEN extract(day from purchase_date::date) < 180 \
THEN 'Yes' ELSE 'No' END AS warranty FROM ppl_cpu_purchases"

cur.execute(dates_n_warr)
cur.fetchall()
# Out:
# [('5399-3484-4724-7187',
#   'gso@qiegan.sqe',
#   'Donyell Ann',
#   'Ospina',
#   '5219459148',
#   'Intel Core i1-7554K',
#   datetime.date(2019, 10, 31),
#   datetime.timedelta(days=241),
#   'Yes'),
#  ('1630-5261-6108-7631',
#   'xnji@gfruaxqnvm.fha',
#   'Bishop',
#   'Siyed',
#   '4164254716',
#   'AMD Ryzen 1 5827X',
#   datetime.date(2017, 7, 16),
#   datetime.timedelta(days=1078),
#   'Yes'),
#  ('4435-3866-1076-3595',
#   'dvyco@tkzhsop.zxg',
#   'Connor',
#   'Powers',
#   '3627413915',
#   'Intel Core i5-9457K',
#   datetime.date(2019, 3, 24),
#   datetime.timedelta(days=462),
#   'Yes'),
#  ('3489-7099-9906-8660',
#   'fy@uvfhplatmz.cam',
#   'Kylie',
#   'Her',
#   '3562764561',
#   'AMD Ryzen 4 3401X',
#   datetime.date(2019, 6, 15),
#   datetime.timedelta(days=379),
#   'Yes'),
#  ('8631-4500-5666-1510',
#   'rztkvliou@dkeinhgysf.deo',
#   'Anthony',
#   'Vo',
#   '7345795348',
#   'Intel Core i6-7283K',
#   datetime.date(2019, 11, 11),
#   datetime.timedelta(days=230),
#   'Yes'),
#  ('1459-9918-1722-7369',
#   'jofmezlbp@iw.evx',
#   'Mutammam',
#   'Mares',
#   '3247247289',
#   'AMD Ryzen 8 9494X',
#   datetime.date(2017, 6, 19),
#   datetime.timedelta(days=1105),
#   'Yes'),
#  ('6736-8932-8180-5826',
#   'ndwofyq@fujnmdw.tai',
#   'Austin',
#   'Sayavong',
#   '1363127632',
#   'Intel Core i3-2473K',
#   datetime.date(2018, 4, 12),
#   datetime.timedelta(days=808),
#   'Yes'),
#  ('1270-8146-6857-9420',
#   'pdw@uwarlpyvgj.unh',
#   'Umaima',
#   'Begay',
#   '5129433167',
#   'AMD Ryzen 1 7620X',
#   datetime.date(2019, 5, 15),
#   datetime.timedelta(days=410),
#   'Yes'),
#  ('5909-1054-2911-2100',
#   'nauvojf@tz.mjc',
#   'Justin',
#   'al-Yousif',
#   '9214512756',
#   'Intel Core i2-9833K',
#   datetime.date(2019, 6, 29),
#   datetime.timedelta(days=365),
#   'Yes'),
#  ('6941-9738-3451-4231',
#   'horaniu@zahobw.ewc',
#   'Shaundra',
#   'Meehan',
#   '8636131763',
#   'AMD Ryzen 1 3408X',
#   datetime.date(2018, 8, 1),
#   datetime.timedelta(days=697),
#   'Yes'),
#  ('7536-4552-2504-7339',
#   'ybt@ehlczprdt.lbd',
#   'Everett',
#   'Vigil',
#   '9722173416',
#   'Intel Core i3-2155K',
#   datetime.date(2020, 3, 7),
#   datetime.timedelta(days=113),
#   'Yes'),
#  ('8095-3531-4870-7852',
#   'jvmrcupeq@yjtwbqfa.yea',
#   'Parker',
#   'al-Hashmi',
#   '4836433459',
#   'AMD Ryzen 9 6314X',
#   datetime.date(2018, 1, 30),
#   datetime.timedelta(days=880),
#   'Yes'),
#  ('7896-9493-5595-1930',
#   'qop@ftaymbje.ynw',
#   'Myranda',
#   'Coronado',
#   '7491694917',
#   'Intel Core i9-7559K',
#   datetime.date(2017, 7, 19),
#   datetime.timedelta(days=1075),
#   'Yes'),
#  ('3324-1139-8494-5870',
#   'glvahfpte@tabin.mtu',
#   'Lee Roy',
#   'Barajas',
#   '5849245874',
#   'AMD Ryzen 1 6392X',
#   datetime.date(2019, 8, 13),
#   datetime.timedelta(days=320),
#   'Yes'),
#  ('9522-9375-2805-4424',
#   'kfzrwnpt@einud.ndm',
#   'Mawzoona',
#   'Arrieta',
#   '4955763519',
#   'Intel Core i2-3637K',
#   datetime.date(2019, 6, 27),
#   datetime.timedelta(days=367),
#   'Yes'),
#  ('1714-9245-5760-6359',
#   'dk@dsntwfcz.rwu',
#   'Neil',
#   'Eskridge',
#   '1289783561',
#   'AMD Ryzen 1 7315X',
#   datetime.date(2018, 10, 18),
#   datetime.timedelta(days=619),
#   'Yes'),
#  ('4408-4558-4472-8661',
#   'cuownkivze@vnpjy.nub',
#   'Estela',
#   'Becker-Dye',
#   '3289278512',
#   'Intel Core i8-6493K',
#   datetime.date(2017, 9, 22),
#   datetime.timedelta(days=1010),
#   'Yes'),
#  ('4135-9194-7119-9359',
#   'bjk@lzaqubg.wnx',
#   'Ryan',
#   'Quintana',
#   '7342518427',
#   'AMD Ryzen 4 3876X',
#   datetime.date(2018, 6, 19),
#   datetime.timedelta(days=740),
#   'Yes'),
#  ('2749-1400-7230-6588',
#   'echp@pwdnhfs.cxq',
#   'Paola',
#   'al-Odeh',
#   '6476823971',
#   'Intel Core i8-9925K',
#   datetime.date(2018, 12, 9),
#   datetime.timedelta(days=567),
#   'Yes'),
#  ('9010-5671-5941-3665',
#   'decbgl@ei.drh',
#   'Brittany',
#   'al-Amin',
#   '4784592536',
#   'AMD Ryzen 9 4796X',
#   datetime.date(2017, 8, 4),
#   datetime.timedelta(days=1059),
#   'Yes'),
#  ('6345-2176-3318-9063',
#   'amhqk@ac.bce',
#   'Simeon',
#   'Ordonez',
#   '9357827241',
#   'Intel Core i3-3413K',
#   datetime.date(2019, 3, 11),
#   datetime.timedelta(days=475),
#   'Yes'),
#  ('5902-4401-4976-2224',
#   'uietxyvdr@rvmpxwdqyu.gpe',
#   'Salvador',
#   'el-Sylla',
#   '9674935689',
#   'AMD Ryzen 5 8636X',
#   datetime.date(2017, 12, 28),
#   datetime.timedelta(days=913),
#   'Yes'),
#  ('3026-7354-5145-7765',
#   'xw@wnuvbtyaeg.grh',
#   'Arnulfo',
#   'Wilson Jr',
#   '5762758349',
#   'Intel Core i5-3338K',
#   datetime.date(2019, 12, 20),
#   datetime.timedelta(days=191),
#   'Yes'),
#  ('5027-1684-3271-9573',
#   'esculkhwaj@lgime.kpd',
#   'Justin',
#   'Vigil',
#   '4639124827',
#   'AMD Ryzen 3 9362X',
#   datetime.date(2018, 11, 29),
#   datetime.timedelta(days=577),
#   'Yes'),
#  ('4266-4647-9544-7225',
#   'bkzy@ozixylp.ixt',
#   'Jade',
#   'el-Qadir',
#   '4121832691',
#   'Intel Core i9-8679K',
#   datetime.date(2019, 1, 9),
#   datetime.timedelta(days=536),
#   'Yes'),
#  ('5205-6735-1953-5341',
#   'roul@ilngkposwq.pzy',
#   'Miranda',
#   'Jones',
#   '6481427816',
#   'AMD Ryzen 4 2744X',
#   datetime.date(2019, 3, 12),
#   datetime.timedelta(days=474),
#   'Yes'),
#  ('5737-9277-9259-1227',
#   'vpzcje@jhtnqoaire.uag',
#   'Juan',
#   'Afuang',
#   '8574182659',
#   'Intel Core i3-1205K',
#   datetime.date(2018, 8, 10),
#   datetime.timedelta(days=688),
#   'Yes'),
#  ('2487-1704-2828-6891',
#   'urszdy@iplejhf.dwl',
#   'Paige',
#   'Burton',
#   '2178936729',
#   'AMD Ryzen 4 2978X',
#   datetime.date(2020, 4, 9),
#   datetime.timedelta(days=80),
#   'Yes'),
#  ('3234-7422-2410-8657',
#   'hiosnmjq@gsop.ndc',
#   'Anna',
#   'al-Abed',
#   '9736934178',
#   'Intel Core i6-9709K',
#   datetime.date(2018, 7, 8),
#   datetime.timedelta(days=721),
#   'Yes'),
#  ('1775-4054-6510-2611',
#   'hnbgvtwkp@lmdhnekay.bkd',
#   'Ambria',
#   'Peterson',
#   '5693972651',
#   'AMD Ryzen 4 8125X',
#   datetime.date(2019, 5, 6),
#   datetime.timedelta(days=419),
#   'Yes'),
#  ('9136-9469-1772-2059',
#   'qas@mxn.sqm',
#   'Kirsten',
#   'Pressley',
#   '6523147826',
#   'Intel Core i1-1119K',
#   datetime.date(2018, 2, 22),
#   datetime.timedelta(days=857),
#   'Yes'),
#  ('8464-3306-8207-9275',
#   'pvjderban@alfcbr.dax',
#   'Ann',
#   'Reish',
#   '5236872168',
#   'AMD Ryzen 4 5508X',
#   datetime.date(2020, 4, 26),
#   datetime.timedelta(days=63),
#   'Yes'),
#  ('6447-6210-9155-9438',
#   'lwysbtujna@tsrzhyjm.wyp',
#   'Joshua',
#   'Brown',
#   '3571528429',
#   'Intel Core i4-6526K',
#   datetime.date(2018, 9, 9),
#   datetime.timedelta(days=658),
#   'Yes'),
#  ('3946-7275-5580-5057',
#   'rvlqgaj@cgd.icx',
#   'Timothy',
#   'el-Rahmani',
#   '9674879473',
#   'AMD Ryzen 9 2992X',
#   datetime.date(2020, 3, 20),
#   datetime.timedelta(days=100),
#   'Yes'),
#  ('9848-8618-5077-2154',
#   'fpd@ci.xpo',
#   'Adrian',
#   'Candelarie',
#   '8137399674',
#   'Intel Core i4-6692K',
#   datetime.date(2018, 12, 11),
#   datetime.timedelta(days=565),
#   'Yes'),
#  ('9532-3331-9347-8684',
#   'fqbunw@vuieanbrgy.qlr',
#   'Alivia',
#   'Madrid',
#   '9353754215',
#   'AMD Ryzen 3 9968X',
#   datetime.date(2017, 12, 19),
#   datetime.timedelta(days=922),
#   'Yes'),
#  ('7006-6971-5842-4183',
#   'tk@ut.wst',
#   'Tuhfa',
#   'Newkirk',
#   '4763646842',
#   'Intel Core i6-3694K',
#   datetime.date(2019, 5, 6),
#   datetime.timedelta(days=419),
#   'Yes'),
#  ('7507-8932-7364-6419',
#   'pbhjusac@iwfxc.lbp',
#   'David',
#   'Segura',
#   '9865187852',
#   'AMD Ryzen 4 1141X',
#   datetime.date(2018, 6, 2),
#   datetime.timedelta(days=757),
#   'Yes'),
#  ('3891-8070-6397-1510',
#   'nrhvft@kzctybv.azb',
#   'Tia',
#   'Bagaporo',
#   '4284352153',
#   'Intel Core i2-7665K',
#   datetime.date(2019, 4, 9),
#   datetime.timedelta(days=446),
#   'Yes'),
#  ('5893-7431-2429-9759',
#   'n@m.jze',
#   'Nicholas',
#   'Stanfield',
#   '3627681469',
#   'AMD Ryzen 4 1840X',
#   datetime.date(2020, 1, 4),
#   datetime.timedelta(days=176),
#   'Yes'),
#  ('2395-5105-9623-2784',
#   'jhxmwqfds@gcybwaeni.sfz',
#   'Tremel',
#   'Byron',
#   '2468245496',
#   'Intel Core i1-8878K',
#   datetime.date(2018, 12, 30),
#   datetime.timedelta(days=546),
#   'Yes'),
#  ('3688-1364-8518-1057',
#   'hagxiclbw@smjqu.ulc',
#   'Sahla',
#   'Wright',
#   '1371956927',
#   'AMD Ryzen 2 8601X',
#   datetime.date(2017, 8, 3),
#   datetime.timedelta(days=1060),
#   'Yes'),
#  ('6444-8155-3435-6170',
#   'vwysoe@zv.ald',
#   'Heaven',
#   'Whitlock',
#   '6143177891',
#   'Intel Core i4-2851K',
#   datetime.date(2019, 11, 18),
#   datetime.timedelta(days=223),
#   'Yes'),
#  ('8347-4503-4773-9918',
#   'urnel@qwblich.ije',
#   'Carlos',
#   'Shambe',
#   '5623769432',
#   'AMD Ryzen 8 7985X',
#   datetime.date(2017, 6, 2),
#   datetime.timedelta(days=1122),
#   'Yes'),
#  ('7232-8736-2101-6158',
#   'inkc@vzbxqi.pjh',
#   'Noe',
#   'el-Farha',
#   '2866131695',
#   'Intel Core i9-2496K',
#   datetime.date(2018, 5, 28),
#   datetime.timedelta(days=762),
#   'Yes'),
#  ('9658-7257-3626-5996',
#   'vs@oe.wyv',
#   'Dhaakir',
#   'Salazar',
#   '1647182741',
#   'AMD Ryzen 7 7209X',
#   datetime.date(2017, 12, 21),
#   datetime.timedelta(days=920),
#   'Yes'),
#  ('2795-5569-8579-5459',
#   'gxjbnh@vpws.xdj',
#   'Kelsie',
#   'Ojeda',
#   '3691257465',
#   'Intel Core i5-8515K',
#   datetime.date(2018, 3, 25),
#   datetime.timedelta(days=826),
#   'Yes'),
#  ('6807-1042-8237-3021',
#   'mparoqyf@otgukl.yig',
#   'Wadha',
#   'Rosser',
#   '2945973569',
#   'AMD Ryzen 5 6859X',
#   datetime.date(2018, 9, 9),
#   datetime.timedelta(days=658),
#   'Yes'),
#  ('8108-1459-6653-3678',
#   'txns@vleywrcdb.hxu',
#   'Daniel',
#   'Lee',
#   '4755345942',
#   'Intel Core i9-6582K',
#   datetime.date(2019, 9, 7),
#   datetime.timedelta(days=295),
#   'Yes'),
#  ('5695-1617-6535-2510',
#   'qfms@jaqhtuzr.psh',
#   'Savannah',
#   'Aragon',
#   '3864823472',
#   'AMD Ryzen 9 6716X',
#   datetime.date(2018, 12, 16),
#   datetime.timedelta(days=560),
#   'Yes'),
#  ('5172-1516-6378-6220',
#   'q@vsxrd.xqz',
#   'Niqualia',
#   'Lee',
#   '9414393295',
#   'Intel Core i1-8481K',
#   datetime.date(2018, 6, 4),
#   datetime.timedelta(days=755),
#   'Yes'),
#  ('7284-4619-6320-4789',
#   'bj@rcizo.fnj',
#   'Yaejin',
#   'Zhang',
#   '2758135486',
#   'AMD Ryzen 8 3237X',
#   datetime.date(2018, 9, 27),
#   datetime.timedelta(days=640),
#   'Yes'),
#  ('5677-6413-2108-4724',
#   'dv@as.xho',
#   'John',
#   'Olukemi',
#   '3973924283',
#   'Intel Core i2-8640K',
#   datetime.date(2020, 3, 27),
#   datetime.timedelta(days=93),
#   'Yes'),
#  ('9425-2374-7516-1153',
#   'rdk@tcyzah.egb',
#   'Elizabeth',
#   'Yarbrough Greenway',
#   '8544921492',
#   'AMD Ryzen 6 5443X',
#   datetime.date(2019, 9, 26),
#   datetime.timedelta(days=276),
#   'Yes'),
#  ('9540-1443-6948-9533',
#   'byrs@kmdwislryj.vkz',
#   'Tiara',
#   'Swift',
#   '6174933247',
#   'Intel Core i4-2378K',
#   datetime.date(2019, 4, 27),
#   datetime.timedelta(days=428),
#   'Yes'),
#  ('9477-3460-3230-7816',
#   'oradlhw@mbc.vlr',
#   'Sipriana',
#   'Buchanan',
#   '5481571562',
#   'AMD Ryzen 2 5168X',
#   datetime.date(2019, 4, 4),
#   datetime.timedelta(days=451),
#   'Yes'),
#  ('9879-2092-1260-3720',
#   'utjyxih@smgtfcvpd.nrh',
#   'Brooke',
#   'Van',
#   '7399768965',
#   'Intel Core i2-5892K',
#   datetime.date(2019, 5, 27),
#   datetime.timedelta(days=398),
#   'Yes'),
#  ('1884-9028-4008-2627',
#   'squwo@neoqi.qur',
#   'Brycen',
#   'Vongrith',
#   '6244219743',
#   'AMD Ryzen 6 8321X',
#   datetime.date(2017, 9, 4),
#   datetime.timedelta(days=1028),
#   'Yes'),
#  ('6989-7525-6667-5379',
#   'may@utkv.lox',
#   'Austin',
#   'el-Shaban',
#   '3848594396',
#   'Intel Core i2-8808K',
#   datetime.date(2020, 3, 6),
#   datetime.timedelta(days=114),
#   'Yes'),
#  ('7968-7074-3976-1576',
#   'thyxlvuzb@b.vsx',
#   'Makaela',
#   'Brown',
#   '3953428136',
#   'AMD Ryzen 3 5459X',
#   datetime.date(2019, 11, 21),
#   datetime.timedelta(days=220),
#   'Yes'),
#  ('5144-2531-4788-8006',
#   'hqsnd@dh.xkg',
#   'Kabeer',
#   'Ripoll-Bunn',
#   '5245161365',
#   'Intel Core i7-9171K',
#   datetime.date(2018, 10, 13),
#   datetime.timedelta(days=624),
#   'Yes'),
#  ('2147-9159-3011-1138',
#   'oynpag@wa.yop',
#   'Faai Z',
#   'el-Hares',
#   '2834751863',
#   'AMD Ryzen 9 5392X',
#   datetime.date(2019, 7, 15),
#   datetime.timedelta(days=349),
#   'Yes'),
#  ('4291-6027-9102-9569',
#   'tbxwlquvp@wdtbqz.crl',
#   'Tiana',
#   'Sanchez',
#   '7812451367',
#   'Intel Core i3-1421K',
#   datetime.date(2018, 1, 24),
#   datetime.timedelta(days=886),
#   'Yes'),
#  ('7332-5925-1286-6862',
#   't@o.etk',
#   'Megana',
#   'Garcia',
#   '8961741498',
#   'AMD Ryzen 7 3174X',
#   datetime.date(2018, 5, 10),
#   datetime.timedelta(days=780),
#   'Yes'),
#  ('7301-7234-8844-7418',
#   'hvalsb@fdnmcyqh.dnl',
#   'Gary',
#   'Todd',
#   '9476526345',
#   'Intel Core i8-1255K',
#   datetime.date(2019, 2, 27),
#   datetime.timedelta(days=487),
#   'Yes'),
#  ('3191-6013-1744-3588',
#   'nodiykujc@mailzwcp.nvl',
#   'Flint',
#   'el-Mansouri',
#   '6917652587',
#   'AMD Ryzen 9 7344X',
#   datetime.date(2018, 6, 1),
#   datetime.timedelta(days=758),
#   'Yes'),
#  ('8729-6644-1036-9535',
#   'xgw@jcroshnufi.lfh',
#   'Summer',
#   'Hightower',
#   '8292617395',
#   'Intel Core i2-2831K',
#   datetime.date(2017, 7, 23),
#   datetime.timedelta(days=1071),
#   'Yes'),
#  ('5270-2055-3136-7595',
#   'zeo@bfxtvijuzg.yug',
#   'Elijah',
#   'Tsegay',
#   '7918749182',
#   'AMD Ryzen 1 8585X',
#   datetime.date(2017, 7, 15),
#   datetime.timedelta(days=1079),
#   'Yes'),
#  ('2053-5744-4578-9197',
#   'ectj@qhxlznsvuf.nlb',
#   'Blain',
#   'Drummond-Moore',
#   '4294781435',
#   'Intel Core i8-9942K',
#   datetime.date(2019, 7, 7),
#   datetime.timedelta(days=357),
#   'Yes'),
#  ('7065-2760-9573-4041',
#   'jeoasgbzc@jbvgyid.nzb',
#   'Je Houng',
#   'Williams',
#   '5481632487',
#   'AMD Ryzen 8 3414X',
#   datetime.date(2018, 9, 6),
#   datetime.timedelta(days=661),
#   'Yes'),
#  ('7820-6222-6952-3433',
#   'vl@hp.rcd',
#   'Brianna',
#   'Cummings',
#   '4893856347',
#   'Intel Core i4-4772K',
#   datetime.date(2019, 12, 25),
#   datetime.timedelta(days=186),
#   'Yes'),
#  ('5992-2519-3286-3804',
#   'qfcv@lcsgq.efj',
#   'Kaalim',
#   'al-Haidar',
#   '7466376741',
#   'AMD Ryzen 6 2350X',
#   datetime.date(2020, 3, 13),
#   datetime.timedelta(days=107),
#   'Yes'),
#  ('6262-3179-2925-7132',
#   'sjnu@fm.fiq',
#   'Naseema',
#   'Wang',
#   '8468411482',
#   'Intel Core i9-3244K',
#   datetime.date(2017, 9, 15),
#   datetime.timedelta(days=1017),
#   'Yes'),
#  ('7760-8782-1912-5001',
#   'd@vniprhdcw.bcv',
#   'Mardiyya',
#   'Coleman',
#   '6816784827',
#   'AMD Ryzen 2 6986X',
#   datetime.date(2019, 9, 2),
#   datetime.timedelta(days=300),
#   'Yes'),
#  ('8418-5661-9895-3053',
#   'h@dcmfg.afp',
#   'Estevan',
#   'Schelhaas',
#   '7485244176',
#   'Intel Core i4-5730K',
#   datetime.date(2017, 9, 29),
#   datetime.timedelta(days=1003),
#   'Yes'),
#  ('8879-4768-9213-2919',
#   'tmehrvjy@rnh.huw',
#   'Eun-Ji',
#   'el-Amen',
#   '1674719278',
#   'AMD Ryzen 2 9227X',
#   datetime.date(2018, 1, 14),
#   datetime.timedelta(days=896),
#   'Yes'),
#  ('1638-3450-6720-2216',
#   'icbjl@doyjzkswau.pev',
#   'Abdul Ghafoor',
#   'Martinez',
#   '8635283548',
#   'Intel Core i2-6252K',
#   datetime.date(2019, 1, 14),
#   datetime.timedelta(days=531),
#   'Yes'),
#  ('9394-6505-1357-1849',
#   'cfayvmo@vyroezms.xha',
#   'Jiyae',
#   'Stepney',
#   '5647629673',
#   'AMD Ryzen 8 6447X',
#   datetime.date(2019, 10, 25),
#   datetime.timedelta(days=247),
#   'Yes'),
#  ('4816-6345-7295-1532',
#   'tmrjcd@y.cte',
#   'Naytasha',
#   'Perkins',
#   '8635293425',
#   'Intel Core i6-5851K',
#   datetime.date(2018, 12, 29),
#   datetime.timedelta(days=547),
#   'Yes'),
#  ('7589-4533-8153-5341',
#   'jekioczb@dq.ioh',
#   'Elijah',
#   'al-Ismael',
#   '4256256498',
#   'AMD Ryzen 2 3499X',
#   datetime.date(2019, 12, 17),
#   datetime.timedelta(days=194),
#   'Yes'),
#  ('4245-7297-5675-9254',
#   'dplkwviamh@jw.omr',
#   'Armando',
#   'Bender',
#   '4732788496',
#   'Intel Core i6-2893K',
#   datetime.date(2018, 1, 14),
#   datetime.timedelta(days=896),
#   'Yes'),
#  ('6823-4543-1578-8809',
#   'cmatxqd@ismdc.vwy',
#   'Julianne',
#   'al-Masih',
#   '6542182759',
#   'AMD Ryzen 8 4182X',
#   datetime.date(2017, 11, 18),
#   datetime.timedelta(days=953),
#   'Yes'),
#  ('9383-2986-3745-3685',
#   'ts@d.qvz',
#   'Kelsey',
#   'el-Firman',
#   '1645637258',
#   'Intel Core i9-6889K',
#   datetime.date(2017, 10, 24),
#   datetime.timedelta(days=978),
#   'Yes'),
#  ('7320-8831-1870-8938',
#   'sjhekqfwad@iz.fmz',
#   'Denise',
#   'Randle',
#   '8757352614',
#   'AMD Ryzen 9 8386X',
#   datetime.date(2019, 4, 12),
#   datetime.timedelta(days=443),
#   'Yes'),
#  ('1701-9601-3440-3882',
#   'jfbzyad@tibvcroha.btc',
#   'Sahla',
#   'Harjo',
#   '8621499634',
#   'Intel Core i2-9892K',
#   datetime.date(2018, 2, 9),
#   datetime.timedelta(days=870),
#   'Yes'),
#  ('8319-1334-3636-1211',
#   'cxg@tvrnefl.ldp',
#   'Marquis',
#   'Yetzbacher',
#   '2181869123',
#   'AMD Ryzen 1 8484X',
#   datetime.date(2018, 3, 19),
#   datetime.timedelta(days=832),
#   'Yes'),
#  ('9257-8444-3772-8816',
#   'ia@fjt.lzx',
#   'Caitlin',
#   'Sailors',
#   '6832452375',
#   'Intel Core i3-7251K',
#   datetime.date(2018, 11, 19),
#   datetime.timedelta(days=587),
#   'Yes'),
#  ('7429-7357-2348-2294',
#   'kpgjb@lmbqv.hcu',
#   'Katelyn',
#   'Reaves',
#   '9819842697',
#   'AMD Ryzen 3 2510X',
#   datetime.date(2019, 3, 31),
#   datetime.timedelta(days=455),
#   'Yes'),
#  ('3978-6232-7972-6896',
#   'eg@yhzjsow.xoz',
#   'Lolita',
#   'el-Burki',
#   '7453483514',
#   'Intel Core i9-7226K',
#   datetime.date(2019, 3, 1),
#   datetime.timedelta(days=485),
#   'Yes'),
#  ('1588-5118-7916-3371',
#   'fkrz@etpusfo.wds',
#   'Caleb',
#   'Song',
#   '4787587986',
#   'AMD Ryzen 2 2158X',
#   datetime.date(2019, 4, 19),
#   datetime.timedelta(days=436),
#   'Yes'),
#  ('1405-7637-3498-2412',
#   'vzqb@frcyklex.tvd',
#   'Javante',
#   'el-Rauf',
#   '6548946894',
#   'Intel Core i9-7458K',
#   datetime.date(2018, 6, 12),
#   datetime.timedelta(days=747),
#   'Yes'),
#  ('7820-6118-9940-9704',
#   'hakjpvnfmg@v.ytl',
#   'Nicole',
#   'Brown',
#   '1272183981',
#   'AMD Ryzen 5 2976X',
#   datetime.date(2020, 4, 18),
#   datetime.timedelta(days=71),
#   'Yes'),
#  ('4449-3183-4160-1712',
#   's@t.kor',
#   "Te'Aisha",
#   'Acosta',
#   '1467568639',
#   'Intel Core i1-3780K',
#   datetime.date(2018, 7, 27),
#   datetime.timedelta(days=702),
#   'Yes'),
#  ('1441-4583-8249-3810',
#   'zmqothjb@etbmczn.uwy',
#   'Richard',
#   'Cartahena Jr',
#   '9277564893',
#   'AMD Ryzen 6 3572X',
#   datetime.date(2018, 1, 4),
#   datetime.timedelta(days=906),
#   'Yes'),
#  ('2952-9151-9898-1765',
#   'dfvo@wdyp.qvu',
#   'Stephanie',
#   'Kirby',
#   '5439659418',
#   'Intel Core i5-2897K',
#   datetime.date(2020, 1, 10),
#   datetime.timedelta(days=170),
#   'Yes'),
#  ('1500-1205-7003-9057',
#   'oxk@alycsmkd.xpl',
#   'Aarti',
#   'Baker',
#   '8636479823',
#   'AMD Ryzen 3 5198X',
#   datetime.date(2019, 8, 15),
#   datetime.timedelta(days=318),
#   'Yes'),
#  ('5080-6821-2207-3979',
#   'kctlqwb@tsqurf.ibv',
#   'Jijo',
#   'al-Asmar',
#   '8912536593',
#   'Intel Core i3-1210K',
#   datetime.date(2018, 2, 28),
#   datetime.timedelta(days=851),
#   'Yes'),
#  ('1844-1953-5997-2517',
#   'b@qwevco.vxu',
#   'Raaid',
#   'Moore Jr',
#   '2862353172',
#   'AMD Ryzen 4 3161X',
#   datetime.date(2017, 11, 28),
#   datetime.timedelta(days=943),
#   'Yes'),
#  ('9840-1987-2588-1658',
#   'sbw@yfbhaiw.zvi',
#   'Amatullah',
#   'Otsuki',
#   '9286874583',
#   'Intel Core i9-1817K',
#   datetime.date(2018, 7, 15),
#   datetime.timedelta(days=714),
#   'Yes'),
#  ('1990-1687-7600-2096',
#   'kjoagyuhtc@gtxwusz.yvi',
#   'Madeleine',
#   'Nesenson',
#   '8154291269',
#   'AMD Ryzen 8 9660X',
#   datetime.date(2019, 5, 4),
#   datetime.timedelta(days=421),
#   'Yes'),
#  ('8667-8810-2373-9481',
#   'xo@stdulfhpig.exa',
#   'Kolten',
#   'al-Ammar',
#   '6951457134',
#   'Intel Core i4-1946K',
#   datetime.date(2018, 9, 9),
#   datetime.timedelta(days=658),
#   'Yes'),
#  ('2236-6201-7818-8583',
#   'zqtrvhkw@ashngbcwq.dwj',
#   'Sunnynam',
#   'Jung',
#   '4135366249',
#   'AMD Ryzen 3 7161X',
#   datetime.date(2018, 2, 7),
#   datetime.timedelta(days=872),
#   'Yes'),
#  ('9242-4807-8509-8118',
#   'xphyi@zsmvcqrehj.thi',
#   'Kyle',
#   'Reed',
#   '4538733169',
#   'Intel Core i3-8304K',
#   datetime.date(2020, 3, 17),
#   datetime.timedelta(days=103),
#   'Yes'),
#  ('2002-8653-3838-5765',
#   'ea@mxorlyupsv.bwg',
#   'Ceara',
#   'Wilson',
#   '2375941329',
#   'AMD Ryzen 2 5658X',
#   datetime.date(2020, 2, 28),
#   datetime.timedelta(days=121),
#   'Yes'),
#  ('2996-4402-5836-5903',
#   'pwnjvl@ehpmygru.ulp',
#   'Rodney',
#   'Vieyra',
#   '6343171354',
#   'Intel Core i1-5613K',
#   datetime.date(2018, 2, 21),
#   datetime.timedelta(days=858),
#   'Yes'),
#  ('6722-5261-1153-3780',
#   'e@zybfjcnlg.omy',
#   'Mikki',
#   'al-Ishak',
#   '5175678597',
#   'AMD Ryzen 8 3897X',
#   datetime.date(2018, 2, 24),
#   datetime.timedelta(days=855),
#   'Yes'),
#  ('9558-2151-7644-6416',
#   'qzwhxlsrm@smlwgfj.cjg',
#   'Emilee',
#   'Duffy',
#   '1845696185',
#   'Intel Core i3-1722K',
#   datetime.date(2019, 6, 11),
#   datetime.timedelta(days=383),
#   'Yes'),
#  ('5286-3197-3034-1827',
#   'tmegsojkh@vuqodxct.vsc',
#   'Taylor',
#   'Mah',
#   '6758413925',
#   'AMD Ryzen 8 6354X',
#   datetime.date(2018, 11, 17),
#   datetime.timedelta(days=589),
#   'Yes'),
#  ('4455-4298-1440-3730',
#   'ceavybtk@cjwrmev.txg',
#   'Christian',
#   'Largo',
#   '5237691627',
#   'Intel Core i2-7380K',
#   datetime.date(2018, 10, 18),
#   datetime.timedelta(days=619),
#   'Yes'),
#  ('5838-6568-8121-7113',
#   'qprhcdsv@rmk.sov',
#   'Edward',
#   'Xayavong',
#   '6734712968',
#   'AMD Ryzen 7 7695X',
#   datetime.date(2019, 4, 2),
#   datetime.timedelta(days=453),
#   'Yes'),
#  ('4728-7601-2532-5388',
#   'rkejgoysua@ofv.jes',
#   'Sarah',
#   'el-Zadeh',
#   '2613276973',
#   'Intel Core i4-5300K',
#   datetime.date(2018, 5, 9),
#   datetime.timedelta(days=781),
#   'Yes'),
#  ('6720-8296-8717-7806',
#   'sroket@udfhbjtnq.ios',
#   'Morgan',
#   'French',
#   '7263596213',
#   'AMD Ryzen 9 9182X',
#   datetime.date(2017, 6, 3),
#   datetime.timedelta(days=1121),
#   'Yes'),
#  ('3569-7475-5882-7842',
#   'qfvilgk@bpsvmlui.tbu',
#   'Haajid',
#   'Jenkins',
#   '5364576279',
#   'Intel Core i7-3688K',
#   datetime.date(2019, 9, 20),
#   datetime.timedelta(days=282),
#   'Yes'),
#  ('6854-9445-3255-3819',
#   'ylfqnkjg@lm.gbz',
#   'Joseph',
#   'Westbrook',
#   '1763747695',
#   'AMD Ryzen 6 5296X',
#   datetime.date(2017, 8, 2),
#   datetime.timedelta(days=1061),
#   'Yes'),
#  ('5272-7222-1055-6377',
#   'wdyflrvt@xvhous.enp',
#   'Brianna',
#   'Van Ort',
#   '7949423147',
#   'Intel Core i6-4515K',
#   datetime.date(2018, 10, 24),
#   datetime.timedelta(days=613),
#   'Yes'),
#  ('5231-7032-5781-9345',
#   'iyhquanpd@wzictarp.uye',
#   'Taylor',
#   'Lee',
#   '1924859362',
#   'AMD Ryzen 5 4559X',
#   datetime.date(2018, 10, 5),
#   datetime.timedelta(days=632),
#   'Yes'),
#  ('2776-3739-7757-5756',
#   'qd@cotaqvlhp.axi',
#   'Haniyya',
#   'Hoover',
#   '2968351264',
#   'Intel Core i1-1611K',
#   datetime.date(2018, 6, 7),
#   datetime.timedelta(days=752),
#   'Yes'),
#  ('5905-2608-1567-9233',
#   'wbfzgkqa@ftjmpzdewq.eqa',
#   'Shahaada',
#   'Burton',
#   '9431474789',
#   'AMD Ryzen 4 4489X',
#   datetime.date(2017, 9, 28),
#   datetime.timedelta(days=1004),
#   'Yes'),
#  ('9946-5827-8011-8545',
#   'dh@risod.unb',
#   'Henry',
#   'Murphy',
#   '8627859683',
#   'Intel Core i3-9863K',
#   datetime.date(2018, 7, 7),
#   datetime.timedelta(days=722),
#   'Yes'),
#  ('1338-5868-1318-1352',
#   'ykdl@t.snh',
#   'Reanne',
#   'Valenzuela',
#   '3163214315',
#   'AMD Ryzen 9 8430X',
#   datetime.date(2019, 4, 23),
#   datetime.timedelta(days=432),
#   'Yes'),
#  ('4191-8359-9492-5056',
#   'beughnsjta@eibhtvwal.svz',
#   'Andrew',
#   'Payton',
#   '4385683879',
#   'Intel Core i1-4243K',
#   datetime.date(2019, 2, 14),
#   datetime.timedelta(days=500),
#   'Yes'),
#  ('1758-6471-8929-2781',
#   'ruft@ip.drj',
#   'Alex',
#   'Acosta',
#   '8728626214',
#   'AMD Ryzen 2 7799X',
#   datetime.date(2019, 11, 18),
#   datetime.timedelta(days=223),
#   'Yes'),
#  ('1643-8401-1622-3845',
#   'qoxfhnkc@kqu.owd',
#   'Azeema',
#   'Hopkins',
#   '5834389176',
#   'Intel Core i4-7414K',
#   datetime.date(2018, 1, 27),
#   datetime.timedelta(days=883),
#   'Yes'),
#  ('2840-4005-4730-1860',
#   'mdcosvkf@cjrptxw.wqr',
#   'Aryan',
#   'Gonzales',
#   '2692467923',
#   'AMD Ryzen 1 5764X',
#   datetime.date(2019, 1, 23),
#   datetime.timedelta(days=522),
#   'Yes'),
#  ('8551-4812-2625-5563',
#   'zop@ghnukz.hfs',
#   'Jordan',
#   'Worley',
#   '2963729213',
#   'Intel Core i6-1712K',
#   datetime.date(2019, 7, 6),
#   datetime.timedelta(days=358),
#   'Yes'),
#  ('8896-1257-6276-1063',
#   'ebrznpmsg@jaivus.kcj',
#   'Skyler',
#   'Shrestha',
#   '8635916571',
#   'AMD Ryzen 1 6134X',
#   datetime.date(2020, 4, 7),
#   datetime.timedelta(days=82),
#   'Yes'),
#  ('3809-6745-2610-6263',
#   'ijhd@mkzufly.wcx',
#   'Kaila',
#   'Pontious',
#   '2783672816',
#   'Intel Core i7-8287K',
#   datetime.date(2018, 6, 6),
#   datetime.timedelta(days=753),
#   'Yes'),
#  ('4272-6653-9811-4192',
#   'q@ktsjv.doh',
#   'Rosa',
#   'Watson',
#   '9428265972',
#   'AMD Ryzen 5 5608X',
#   datetime.date(2019, 8, 21),
#   datetime.timedelta(days=312),
#   'Yes'),
#  ('8461-8835-7484-1767',
#   'ix@vrfqonbi.ydl',
#   'Lisa',
#   'Baker',
#   '5922317245',
#   'Intel Core i4-5783K',
#   datetime.date(2018, 7, 23),
#   datetime.timedelta(days=706),
#   'Yes'),
#  ('4343-1684-8617-3527',
#   'wqbxekus@elwkmpaj.ejx',
#   'Daniel',
#   'Ta',
#   '3873794613',
#   'AMD Ryzen 2 9434X',
#   datetime.date(2019, 8, 12),
#   datetime.timedelta(days=321),
#   'Yes'),
#  ('4720-2092-7141-8712',
#   'ihvspgj@dipfgabtr.zxp',
#   'Shaakira',
#   'al-Rabbani',
#   '7928165392',
#   'Intel Core i4-7423K',
#   datetime.date(2019, 6, 15),
#   datetime.timedelta(days=379),
#   'Yes'),
#  ('9966-2168-5049-2233',
#   'znky@gsdwqa.mzj',
#   'Rosario',
#   'al-Miah',
#   '9416198341',
#   'AMD Ryzen 9 3170X',
#   datetime.date(2019, 12, 18),
#   datetime.timedelta(days=193),
#   'Yes'),
#  ('7695-7099-2739-7962',
#   'sabcikt@xeozdub.etd',
#   "Ta'Rell",
#   'Venegas Gonzalez',
#   '8729718547',
#   'Intel Core i6-9316K',
#   datetime.date(2019, 7, 12),
#   datetime.timedelta(days=352),
#   'Yes'),
#  ('7677-6298-1629-6411',
#   'ugvr@hsqodpuxe.hga',
#   'Janika',
#   'Cordova',
#   '3788712869',
#   'AMD Ryzen 8 2565X',
#   datetime.date(2017, 9, 1),
#   datetime.timedelta(days=1031),
#   'Yes'),
#  ('5931-2883-4940-7407',
#   'j@nsporm.hyt',
#   'Jordan',
#   'al-Shafi',
#   '6583826824',
#   'Intel Core i3-5607K',
#   datetime.date(2018, 2, 9),
#   datetime.timedelta(days=870),
#   'Yes'),
#  ('2662-6430-9016-3603',
#   'qd@xdol.vyc',
#   'Jhonathon',
#   'Singh',
#   '2975347139',
#   'AMD Ryzen 7 7558X',
#   datetime.date(2019, 6, 26),
#   datetime.timedelta(days=368),
#   'Yes'),
#  ('8233-3553-7350-4143',
#   'aqucnfhz@vtef.vcu',
#   'Santee',
#   'Vega',
#   '4362355976',
#   'Intel Core i5-4869K',
#   datetime.date(2020, 4, 8),
#   datetime.timedelta(days=81),
#   'Yes'),
#  ('7927-1085-2509-6183',
#   'slu@fzxqgip.tkg',
#   'Ashley',
#   'Rodriguez-Sierra',
#   '2562175924',
#   'AMD Ryzen 2 3981X',
#   datetime.date(2019, 5, 13),
#   datetime.timedelta(days=412),
#   'Yes'),
#  ('4923-4367-2803-5070',
#   'u@zlbnue.eix',
#   'Mumina',
#   'Nelson',
#   '8465976871',
#   'Intel Core i9-7890K',
#   datetime.date(2019, 2, 9),
#   datetime.timedelta(days=505),
#   'Yes'),
#  ('8188-8246-6389-5994',
#   'iwb@pxicudgvo.kyq',
#   'Kenneth',
#   'Baca',
#   '6739639857',
#   'AMD Ryzen 1 2276X',
#   datetime.date(2017, 12, 23),
#   datetime.timedelta(days=918),
#   'Yes'),
#  ('4859-3009-2809-6487',
#   'fkhvrcogp@cymgvxuh.rnt',
#   'Joe',
#   'Puryear',
#   '2373621749',
#   'Intel Core i4-3697K',
#   datetime.date(2019, 3, 11),
#   datetime.timedelta(days=475),
#   'Yes'),
#  ('5335-1048-2818-9648',
#   'jdhwlftgyn@aqobn.ier',
#   'Alexander',
#   'Harris',
#   '2457341279',
#   'AMD Ryzen 2 2295X',
#   datetime.date(2019, 9, 14),
#   datetime.timedelta(days=288),
#   'Yes'),
#  ('5040-3662-8853-7883',
#   'lxqvgjw@sur.inl',
#   'Evangelina',
#   'Whitelance III',
#   '9816816492',
#   'Intel Core i6-6170K',
#   datetime.date(2019, 11, 21),
#   datetime.timedelta(days=220),
#   'Yes'),
#  ('1280-4584-5250-1133',
#   'axthrlcob@kdqvoabtw.nmg',
#   'Anthony',
#   'Henley',
#   '6958349723',
#   'AMD Ryzen 1 1674X',
#   datetime.date(2018, 11, 20),
#   datetime.timedelta(days=586),
#   'Yes'),
#  ('1268-4649-1889-9493',
#   'oyaxzbnfd@ysp.qnv',
#   'Sarah',
#   'Martinez',
#   '9757419172',
#   'Intel Core i1-8436K',
#   datetime.date(2019, 9, 10),
#   datetime.timedelta(days=292),
#   'Yes'),
#  ('7940-2137-2526-1167',
#   'fr@do.hmt',
#   'Micha',
#   'Dus',
#   '8138436581',
#   'AMD Ryzen 5 6747X',
#   datetime.date(2019, 1, 19),
#   datetime.timedelta(days=526),
#   'Yes'),
#  ('9837-1217-1305-9401',
#   'tdkpgj@zukcotjdfv.smx',
#   'Sean',
#   'el-Toure',
#   '9876942643',
#   'Intel Core i2-3685K',
#   datetime.date(2019, 6, 27),
#   datetime.timedelta(days=367),
#   'Yes'),
#  ('4581-8717-5316-8278',
#   'xcukr@msre.uln',
#   'Christina',
#   'Trustee',
#   '5294387139',
#   'AMD Ryzen 7 8559X',
#   datetime.date(2020, 5, 21),
#   datetime.timedelta(days=38),
#   'Yes'),
#  ('1735-8833-7021-2227',
#   'icvqsr@vhigapywze.ego',
#   'Brandon',
#   'Arellano',
#   '5648458534',
#   'Intel Core i2-6566K',
#   datetime.date(2018, 2, 8),
#   datetime.timedelta(days=871),
#   'Yes'),
#  ('5455-5818-7572-4269',
#   'v@myfcw.asg',
#   'Rachel',
#   'Walker',
#   '3959843495',
#   'AMD Ryzen 7 7653X',
#   datetime.date(2019, 10, 11),
#   datetime.timedelta(days=261),
#   'Yes'),
#  ('4803-5742-4135-2035',
#   'kewmojrs@nz.xou',
#   'Ashleigh',
#   'el-Emami',
#   '8763869172',
#   'Intel Core i4-7954K',
#   datetime.date(2019, 4, 12),
#   datetime.timedelta(days=443),
#   'Yes'),
#  ('5362-7782-9258-9194',
#   'fd@cuk.bkx',
#   'Chamiya',
#   'Smoot',
#   '7682692815',
#   'AMD Ryzen 9 1218X',
#   datetime.date(2017, 10, 27),
#   datetime.timedelta(days=975),
#   'Yes'),
#  ('9163-9751-4187-7248',
#   'juvifeak@ocz.yrm',
#   'Suhail',
#   'Mcgregor',
#   '2755865849',
#   'Intel Core i9-8415K',
#   datetime.date(2019, 3, 2),
#   datetime.timedelta(days=484),
#   'Yes'),
#  ('6900-8855-1116-8340',
#   'klj@h.dtm',
#   'Zekeal',
#   'al-Mady',
#   '1848417263',
#   'AMD Ryzen 5 3553X',
#   datetime.date(2017, 7, 20),
#   datetime.timedelta(days=1074),
#   'Yes'),
#  ('4936-5123-7841-8311',
#   'ln@tzmdkbhivp.mju',
#   'Eliza',
#   'Rollins',
#   '9157931975',
#   'Intel Core i1-6560K',
#   datetime.date(2017, 5, 31),
#   datetime.timedelta(days=1124),
#   'Yes'),
#  ('6350-5674-3238-1149',
#   'cwa@ga.xdc',
#   'Dillon Noah',
#   'al-Islam',
#   '7236752975',
#   'AMD Ryzen 8 2964X',
#   datetime.date(2019, 4, 8),
#   datetime.timedelta(days=447),
#   'Yes'),
#  ('6295-2671-2503-4101',
#   'qjegsury@pysfx.qag',
#   'Gabriell',
#   'Hall',
#   '5964823749',
#   'Intel Core i9-7140K',
#   datetime.date(2019, 9, 5),
#   datetime.timedelta(days=297),
#   'Yes'),
#  ('7376-4009-9640-3049',
#   'kmc@prfb.swf',
#   'Saamyya',
#   'Ortiz',
#   '9216541924',
#   'AMD Ryzen 8 1912X',
#   datetime.date(2017, 9, 4),
#   datetime.timedelta(days=1028),
#   'Yes'),
#  ('2631-3788-3215-5496',
#   'zu@diezanbur.fpi',
#   'Ivan',
#   'Crespin',
#   '1233866849',
#   'Intel Core i6-6986K',
#   datetime.date(2017, 8, 13),
#   datetime.timedelta(days=1050),
#   'Yes'),
#  ('7182-5087-1718-9167',
#   'xbsyhkz@vusfpmjibh.tyq',
#   'Amanda',
#   'Hope',
#   '7617518921',
#   'AMD Ryzen 2 3130X',
#   datetime.date(2018, 11, 21),
#   datetime.timedelta(days=585),
#   'Yes'),
#  ('6780-9581-6358-5425',
#   'spnaybvx@dbrxuwfh.eyp',
#   'Joseph',
#   'Todd',
#   '2679516715',
#   'Intel Core i6-2578K',
#   datetime.date(2017, 10, 18),
#   datetime.timedelta(days=984),
#   'Yes'),
#  ('8862-2255-9655-3599',
#   'eidgjbx@labcz.baw',
#   'Karen',
#   'al-Farag',
#   '8942798364',
#   'AMD Ryzen 8 9275X',
#   datetime.date(2018, 1, 18),
#   datetime.timedelta(days=892),
#   'Yes'),
#  ('1942-9410-6860-8879',
#   'hqegnfd@pau.lxz',
#   'Wajeeb',
#   'Park',
#   '2565924319',
#   'Intel Core i8-1115K',
#   datetime.date(2017, 11, 11),
#   datetime.timedelta(days=960),
#   'Yes'),
#  ('1477-1198-9967-2197',
#   'cx@qdsnv.fxq',
#   'Jordan',
#   'Greenfield',
#   '3128953547',
#   'AMD Ryzen 5 6621X',
#   datetime.date(2019, 12, 27),
#   datetime.timedelta(days=184),
#   'Yes'),
#  ('3929-7105-2047-2518',
#   'qwzisp@ivpqg.twc',
#   'Johny',
#   'Tamerat',
#   '6739654713',
#   'Intel Core i3-1158K',
#   datetime.date(2019, 5, 2),
#   datetime.timedelta(days=423),
#   'Yes'),
#  ('5945-4570-3756-7534',
#   'gku@tkelni.ctn',
#   'Khairi',
#   'Wall',
#   '7894166217',
#   'AMD Ryzen 1 9708X',
#   datetime.date(2019, 6, 19),
#   datetime.timedelta(days=375),
#   'Yes'),
#  ('2680-5349-2031-1897',
#   'ubdvpz@abshrljnxd.zor',
#   'Abdul Ghafoor',
#   'Rumley',
#   '8213981972',
#   'Intel Core i4-7381K',
#   datetime.date(2017, 12, 29),
#   datetime.timedelta(days=912),
#   'Yes'),
#  ('3580-5949-4055-7190',
#   'xbj@jvgxe.qhr',
#   'Dylan',
#   'Gashwazra',
#   '2657391284',
#   'AMD Ryzen 6 2344X',
#   datetime.date(2019, 5, 9),
#   datetime.timedelta(days=416),
#   'Yes'),
#  ('2529-7966-9829-5901',
#   'jwovhins@qbkfhaw.lft',
#   'Daniel',
#   'Calderon-Stroschein',
#   '5345742134',
#   'Intel Core i2-8712K',
#   datetime.date(2019, 4, 5),
#   datetime.timedelta(days=450),
#   'Yes'),
#  ('4468-5725-2073-3876',
#   'mp@vwhubltzys.kwq',
#   'Shelby',
#   'el-Firman',
#   '6599253217',
#   'AMD Ryzen 1 2326X',
#   datetime.date(2019, 7, 14),
#   datetime.timedelta(days=350),
#   'Yes'),
#  ('2656-6778-9667-9984',
#   'i@bshnerj.rsf',
#   'Maria',
#   'Quarles',
#   '6584524591',
#   'Intel Core i8-8972K',
#   datetime.date(2019, 4, 21),
#   datetime.timedelta(days=434),
#   'Yes'),
#  ('5893-8340-6916-2299',
#   'iaps@xpokhj.xlu',
#   'Kincaid',
#   'el-Khalili',
#   '6815835639',
#   'AMD Ryzen 2 1134X',
#   datetime.date(2018, 11, 11),
#   datetime.timedelta(days=595),
#   'Yes'),
#  ('5575-9087-1852-4900',
#   'yvkj@mxywcs.gbo',
#   'Jamie',
#   'Hull',
#   '7583657693',
#   'Intel Core i7-4996K',
#   datetime.date(2018, 7, 3),
#   datetime.timedelta(days=726),
#   'Yes'),
#  ('1320-8094-5183-6336',
#   'xedyh@ios.csh',
#   'Noori',
#   'Galbearth',
#   '8456758643',
#   'AMD Ryzen 7 1290X',
#   datetime.date(2020, 5, 15),
#   datetime.timedelta(days=44),
#   'Yes'),
#  ('9186-6957-7069-5322',
#   'sbuvzirpq@o.pyw',
#   'Basheer',
#   'Slee Ackerson',
#   '8751733257',
#   'Intel Core i6-1130K',
#   datetime.date(2019, 5, 8),
#   datetime.timedelta(days=417),
#   'Yes'),
#  ('4102-5171-6753-9061',
#   'uszjricadg@wydz.poj',
#   'Mustafa',
#   'Lamp',
#   '6231838375',
#   'AMD Ryzen 8 6517X',
#   datetime.date(2019, 3, 15),
#   datetime.timedelta(days=471),
#   'Yes'),
#  ('9442-1192-6147-3749',
#   'k@lzkrbqj.aou',
#   'Ajai',
#   'Ramirez',
#   '1876927928',
#   'Intel Core i2-6549K',
#   datetime.date(2018, 10, 19),
#   datetime.timedelta(days=618),
#   'Yes'),
#  ('1380-7023-4257-6761',
#   'suehnjda@jvgzaix.zaj',
#   'Tanner',
#   'Bralich',
#   '8656171865',
#   'AMD Ryzen 1 6133X',
#   datetime.date(2020, 3, 1),
#   datetime.timedelta(days=119),
#   'Yes'),
#  ('9124-4588-2293-3628',
#   'pdqrfins@guwkzp.fzl',
#   'Londyn',
#   'Tisdel',
#   '3173895429',
#   'Intel Core i1-4288K',
#   datetime.date(2019, 8, 12),
#   datetime.timedelta(days=321),
#   'Yes'),
#  ('6622-4873-5447-6397',
#   'ytd@driebsjq.jva',
#   'Dejanee',
#   'Shiba',
#   '7415161648',
#   'AMD Ryzen 6 5406X',
#   datetime.date(2019, 8, 18),
#   datetime.timedelta(days=315),
#   'Yes'),
#  ('2102-6112-7807-9289',
#   'cg@wajusenzr.hkm',
#   'Charles',
#   'Palomino',
#   '8761643981',
#   'Intel Core i3-3435K',
#   datetime.date(2018, 1, 20),
#   datetime.timedelta(days=890),
#   'Yes'),
#  ('7648-2137-7681-5318',
#   'tgbqvr@idwaqxk.hkx',
#   'Mitsy',
#   'Petersen',
#   '5787491724',
#   'AMD Ryzen 3 5368X',
#   datetime.date(2018, 5, 30),
#   datetime.timedelta(days=760),
#   'Yes'),
#  ('8557-8690-4999-7792',
#   'syahbncpeq@zchqkmdubj.zwb',
#   'Akhilesh',
#   'Fuentes',
#   '8438611273',
#   'Intel Core i3-2282K',
#   datetime.date(2018, 10, 10),
#   datetime.timedelta(days=627),
#   'Yes'),
#  ('2604-8302-6119-3664',
#   'ufbaenrc@nd.hbu',
#   'Naafoora',
#   'Young',
#   '2893492783',
#   'AMD Ryzen 6 7662X',
#   datetime.date(2020, 1, 13),
#   datetime.timedelta(days=167),
#   'Yes'),
#  ('2432-5074-9422-2947',
#   'fijmoyvc@cmzfv.mbc',
#   'Rebecca',
#   'Cervantes Morales',
#   '4214973681',
#   'Intel Core i9-5675K',
#   datetime.date(2017, 7, 17),
#   datetime.timedelta(days=1077),
#   'Yes'),
#  ('7234-8904-8381-4154',
#   'xirsfq@uf.mwu',
#   'Ryan',
#   'el-Anwar',
#   '6211458423',
#   'AMD Ryzen 5 8526X',
#   datetime.date(2020, 4, 28),
#   datetime.timedelta(days=61),
#   'Yes'),
#  ('2316-9995-4478-7422',
#   'itunzmqp@q.zub',
#   'Andrea',
#   'Vue',
#   '7125849561',
#   'Intel Core i5-2795K',
#   datetime.date(2018, 3, 26),
#   datetime.timedelta(days=825),
#   'Yes'),
#  ('9977-6665-6790-9118',
#   'fudyevgcrx@lsrxehqmn.rhv',
#   'Laquasea',
#   'Garcia',
#   '4623196982',
#   'AMD Ryzen 2 3252X',
#   datetime.date(2020, 2, 19),
#   datetime.timedelta(days=130),
#   'Yes'),
#  ('3001-8862-8096-3197',
#   'jybhxz@utgrmve.mav',
#   'David',
#   'Cates',
#   '2155349418',
#   'Intel Core i7-7299K',
#   datetime.date(2019, 11, 27),
#   datetime.timedelta(days=214),
#   'Yes'),
#  ('6634-4372-2570-3931',
#   'foh@jdpwugszi.wrm',
#   'Latasha',
#   'Atene',
#   '7982758457',
#   'AMD Ryzen 8 3507X',
#   datetime.date(2019, 11, 6),
#   datetime.timedelta(days=235),
#   'Yes'),
#  ('7745-2551-4417-1871',
#   'bktjpq@wbkcidjrgv.xue',
#   'Jonathan',
#   'Schenally',
#   '2497241584',
#   'Intel Core i1-3414K',
#   datetime.date(2020, 1, 28),
#   datetime.timedelta(days=152),
#   'Yes'),
#  ('2984-9954-9120-8239',
#   'kpxwbchya@txfrmknbh.bag',
#   'Jumaima',
#   'Marial',
#   '3782465816',
#   'AMD Ryzen 1 5529X',
#   datetime.date(2019, 6, 10),
#   datetime.timedelta(days=384),
#   'Yes'),
#  ('3111-8096-9936-8359',
#   'mtsndylfkv@pvgt.ghi',
#   'Marcus',
#   'Herbst',
#   '7259873276',
#   'Intel Core i6-1320K',
#   datetime.date(2017, 7, 4),
#   datetime.timedelta(days=1090),
#   'Yes'),
#  ('2105-9534-1591-1167',
#   'evbhkpts@pbtz.xun',
#   'Joe',
#   'el-Amiri',
#   '6438975297',
#   'AMD Ryzen 6 7648X',
#   datetime.date(2017, 11, 23),
#   datetime.timedelta(days=948),
#   'Yes'),
#  ('8553-1260-9347-6261',
#   'ecivtousw@vtlf.nco',
#   'Roberto',
#   'Donaldson',
#   '3711475238',
#   'Intel Core i6-5909K',
#   datetime.date(2018, 8, 30),
#   datetime.timedelta(days=668),
#   'Yes'),
#  ('3100-7239-5639-9856',
#   'rmn@wnmydchaij.prz',
#   'Dandrew',
#   'Ronnebaum',
#   '6127254672',
#   'AMD Ryzen 4 8146X',
#   datetime.date(2019, 4, 3),
#   datetime.timedelta(days=452),
#   'Yes'),
#  ('2403-1080-7272-1357',
#   'cin@zydfx.gtb',
#   'Frederick',
#   'Semp',
#   '8969583597',
#   'Intel Core i9-1902K',
#   datetime.date(2018, 6, 13),
#   datetime.timedelta(days=746),
#   'Yes'),
#  ('7962-7831-9292-8109',
#   'uoi@poqwvita.fpa',
#   'Raaji',
#   'el-Dawood',
#   '7343698671',
#   'AMD Ryzen 9 8701X',
#   datetime.date(2018, 8, 19),
#   datetime.timedelta(days=679),
#   'Yes'),
#  ('6549-3277-4107-1127',
#   'kbrfmslc@mljvkxy.hap',
#   'Evan',
#   'Courchene',
#   '4192577213',
#   'Intel Core i5-1379K',
#   datetime.date(2017, 10, 12),
#   datetime.timedelta(days=990),
#   'Yes'),
#  ('2356-2470-3547-2454',
#   'wrqhf@jfkrlasn.fib',
#   'Sheyanne',
#   'Russo',
#   '4519341485',
#   'AMD Ryzen 6 1889X',
#   datetime.date(2017, 8, 6),
#   datetime.timedelta(days=1057),
#   'Yes'),
#  ('8105-9133-4352-3318',
#   'qhlu@lojaqtgyc.xhr',
#   'Thien',
#   'Stevenson',
#   '5319375243',
#   'Intel Core i6-9893K',
#   datetime.date(2019, 12, 10),
#   datetime.timedelta(days=201),
#   'Yes'),
#  ('4809-3611-5666-2347',
#   't@vtlizhkxen.jud',
#   'Jeremiah',
#   'al-Mahmood',
#   '5493698327',
#   'AMD Ryzen 1 7368X',
#   datetime.date(2019, 9, 29),
#   datetime.timedelta(days=273),
#   'Yes'),
#  ('4425-7441-7735-9550',
#   'f@qjg.kfs',
#   'Amjad',
#   'Sheahan',
#   '5976913179',
#   'Intel Core i8-1287K',
#   datetime.date(2017, 11, 7),
#   datetime.timedelta(days=964),
#   'Yes'),
#  ('4801-7454-2162-1850',
#   'no@odc.dva',
#   'Jordan',
#   'Williams',
#   '7289521936',
#   'AMD Ryzen 8 7923X',
#   datetime.date(2018, 8, 13),
#   datetime.timedelta(days=685),
#   'Yes'),
#  ('3094-8352-2644-2370',
#   'lpxsd@mzs.muo',
#   'Phu',
#   'Lopez Martinez',
#   '4271564917',
#   'Intel Core i3-6865K',
#   datetime.date(2018, 2, 3),
#   datetime.timedelta(days=876),
#   'Yes'),
#  ('2683-6119-5811-2066',
#   'anzf@fzqiwhavor.zgk',
#   'Meseret',
#   'Sparks',
#   '3916874735',
#   'AMD Ryzen 3 6434X',
#   datetime.date(2020, 4, 1),
#   datetime.timedelta(days=88),
#   'Yes'),
#  ('3178-9178-3478-5064',
#   'k@neaot.nsc',
#   'Cayla',
#   'Minutolo',
#   '5989214318',
#   'Intel Core i3-5912K',
#   datetime.date(2019, 6, 7),
#   datetime.timedelta(days=387),
#   'Yes'),
#  ('4829-5860-4578-4890',
#   'ue@cqakiowb.pic',
#   'Melissa',
#   'Largo',
#   '8964953192',
#   'AMD Ryzen 3 3576X',
#   datetime.date(2018, 1, 1),
#   datetime.timedelta(days=909),
#   'Yes'),
#  ('7442-8229-3511-1429',
#   'gt@ofupyhdg.hpx',
#   'Kimberly',
#   'Carl',
#   '5233195269',
#   'Intel Core i3-5646K',
#   datetime.date(2018, 12, 8),
#   datetime.timedelta(days=568),
#   'Yes'),
#  ('5877-5345-4100-2873',
#   'bp@wid.qco',
#   'Hazm',
#   'Tutt',
#   '5463623651',
#   'AMD Ryzen 5 6625X',
#   datetime.date(2019, 12, 7),
#   datetime.timedelta(days=204),
#   'Yes'),
#  ('6921-1083-1797-8702',
#   'xzgefkqlh@nhocyb.qwy',
#   'Anthony',
#   'Hazelman',
#   '9315684987',
#   'Intel Core i1-5751K',
#   datetime.date(2019, 2, 8),
#   datetime.timedelta(days=506),
#   'Yes'),
#  ('3758-4837-8229-5538',
#   'iwdvlfmoqc@npqv.sot',
#   'Pedro',
#   'Ortiz',
#   '5296812586',
#   'AMD Ryzen 6 5491X',
#   datetime.date(2018, 3, 21),
#   datetime.timedelta(days=830),
#   'Yes'),
#  ('6540-7588-8788-8563',
#   'bjy@hcafqgby.gah',
#   'Courtney',
#   'Pacheco',
#   '7327495376',
#   'Intel Core i1-7446K',
#   datetime.date(2018, 11, 21),
#   datetime.timedelta(days=585),
#   'Yes'),
#  ('6509-6877-9465-6126',
#   'wsm@iauemrnw.ayg',
#   'Rutaiba',
#   'el-Mahdavi',
#   '4287194827',
#   'AMD Ryzen 5 8789X',
#   datetime.date(2018, 3, 6),
#   datetime.timedelta(days=845),
#   'Yes'),
#  ('8213-6734-3312-6820',
#   'bhsxizeufa@onupxthf.cqj',
#   'Jenberu',
#   'Wolday',
#   '4616953594',
#   'Intel Core i8-4852K',
#   datetime.date(2017, 9, 27),
#   datetime.timedelta(days=1005),
#   'Yes'),
#  ('9186-3808-5466-7453',
#   'gtnqmzyib@yrseczf.aew',
#   'Jeremy',
#   'Hicks',
#   '4311543719',
#   'AMD Ryzen 1 7578X',
#   datetime.date(2019, 12, 1),
#   datetime.timedelta(days=210),
#   'Yes'),
#  ('8809-5639-6902-2564',
#   'luvs@dw.utx',
#   'Sadeeqa',
#   'Mcdowell',
#   '2354352541',
#   'Intel Core i5-5191K',
#   datetime.date(2018, 3, 25),
#   datetime.timedelta(days=826),
#   'Yes'),
#  ('3408-5956-2160-3750',
#   'onzjvsy@crw.trb',
#   'Lutfiyya',
#   'el-Karimi',
#   '8237897238',
#   'AMD Ryzen 1 4754X',
#   datetime.date(2019, 3, 20),
#   datetime.timedelta(days=466),
#   'Yes'),
#  ('3114-3966-1746-6760',
#   'c@jdoycz.qlv',
#   'Davis',
#   'Owens',
#   '6745373925',
#   'Intel Core i2-1692K',
#   datetime.date(2018, 4, 14),
#   datetime.timedelta(days=806),
#   'Yes'),
#  ('6013-9638-9219-7881',
#   'vojktdpy@epnrivaq.oty',
#   'David',
#   'Rausch',
#   '2499579486',
#   'AMD Ryzen 8 6502X',
#   datetime.date(2017, 10, 23),
#   datetime.timedelta(days=979),
#   'Yes'),
#  ('3429-9815-4186-2094',
#   'dyw@yos.vae',
#   'Hadiyya',
#   'Young',
#   '5747535126',
#   'Intel Core i2-1960K',
#   datetime.date(2020, 4, 24),
#   datetime.timedelta(days=65),
#   'Yes'),
#  ('9889-3446-8374-6805',
#   'wuierq@vhzrq.jew',
#   'Nicholas',
#   'el-Arafat',
#   '6593943526',
#   'AMD Ryzen 1 6955X',
#   datetime.date(2018, 9, 18),
#   datetime.timedelta(days=649),
#   'Yes'),
#  ('2654-8117-1430-2187',
#   'cgst@v.dtk',
#   'Katie',
#   'Lucero Reyes',
#   '1629216934',
#   'Intel Core i4-4881K',
#   datetime.date(2019, 5, 17),
#   datetime.timedelta(days=408),
#   'Yes'),
#  ('4407-6167-5325-2238',
#   'vyugzc@uqretgbd.rbu',
#   'Thai',
#   'Do',
#   '5787381869',
#   'AMD Ryzen 7 3881X',
#   datetime.date(2020, 5, 11),
#   datetime.timedelta(days=48),
#   'Yes'),
#  ('5339-3730-3400-1185',
#   'eqtlg@jct.gpv',
#   'Kevin',
#   'Floyd',
#   '7931633925',
#   'Intel Core i9-5475K',
#   datetime.date(2019, 8, 16),
#   datetime.timedelta(days=317),
#   'Yes'),
#  ('1332-5428-8703-2266',
#   'kcnzexv@zqirvdlgyu.rui',
#   'Juanita',
#   'Lamont',
#   '2537154391',
#   'AMD Ryzen 4 8539X',
#   datetime.date(2019, 3, 15),
#   datetime.timedelta(days=471),
#   'Yes'),
#  ('3190-3779-6889-9603',
#   'clft@vhriydnxpm.vyf',
#   'Audrianna',
#   'al-Odeh',
#   '4699543841',
#   'Intel Core i2-2692K',
#   datetime.date(2019, 4, 22),
#   datetime.timedelta(days=433),
#   'Yes'),
#  ('7642-9342-1745-3044',
#   'd@ruw.yzp',
#   'Sarah',
#   'Waite',
#   '3151648791',
#   'AMD Ryzen 4 8590X',
#   datetime.date(2020, 3, 23),
#   datetime.timedelta(days=97),
#   'Yes'),
#  ('2869-8935-1273-3753',
#   'i@vmgskchpq.aor',
#   'Arhab',
#   'Cline',
#   '3471857695',
#   'Intel Core i5-4581K',
#   datetime.date(2019, 10, 6),
#   datetime.timedelta(days=266),
#   'Yes'),
#  ('5424-1590-5401-3631',
#   'inkxrzq@fakds.ifb',
#   'Alysha',
#   'Loya',
#   '8124693574',
#   'AMD Ryzen 2 8629X',
#   datetime.date(2018, 4, 15),
#   datetime.timedelta(days=805),
#   'Yes'),
#  ('1286-7361-2770-3991',
#   'wn@fqjd.chf',
#   'Muntaha',
#   'Parmiter',
#   '7451853829',
#   'Intel Core i9-4869K',
#   datetime.date(2018, 7, 14),
#   datetime.timedelta(days=715),
#   'Yes'),
#  ('5348-8663-5336-8783',
#   'kamq@qfxohtcemi.mjw',
#   'Abagail',
#   'Braley',
#   '3746835831',
#   'AMD Ryzen 9 9162X',
#   datetime.date(2019, 12, 11),
#   datetime.timedelta(days=200),
#   'Yes'),
#  ('9355-7704-7762-9380',
#   'q@p.fgh',
#   'Andrew',
#   'Chen',
#   '1538972576',
#   'Intel Core i7-8644K',
#   datetime.date(2018, 12, 13),
#   datetime.timedelta(days=563),
#   'Yes'),
#  ('4894-3442-6381-6422',
#   'qjc@v.mwe',
#   'Azza',
#   'Singleton',
#   '8954329237',
#   'AMD Ryzen 3 7795X',
#   datetime.date(2017, 11, 23),
#   datetime.timedelta(days=948),
#   'Yes'),
#  ('7393-5844-4483-9562',
#   'ykn@wveuxsld.apc',
#   'Morgan',
#   'Larsen',
#   '3966582637',
#   'Intel Core i8-5756K',
#   datetime.date(2020, 1, 26),
#   datetime.timedelta(days=154),
#   'Yes'),
#  ('5815-5714-1186-6737',
#   'b@wqb.oxc',
#   'Jamice',
#   'Agard',
#   '3545849683',
#   'AMD Ryzen 2 6291X',
#   datetime.date(2020, 1, 26),
#   datetime.timedelta(days=154),
#   'Yes'),
#  ('3388-9288-1720-9622',
#   'ysbe@ldajvymbqu.nga',
#   'Diana',
#   'Song',
#   '6212544297',
#   'Intel Core i5-2332K',
#   datetime.date(2017, 6, 8),
#   datetime.timedelta(days=1116),
#   'Yes'),
#  ('3692-6101-8243-2125',
#   'nfvr@xwig.maw',
#   'Gary',
#   'Pinon',
#   '6399419387',
#   'AMD Ryzen 9 5166X',
#   datetime.date(2018, 4, 17),
#   datetime.timedelta(days=803),
#   'Yes'),
#  ('6340-6375-1827-2701',
#   'xrdylhu@s.nqc',
#   'Deliah',
#   'al-Farra',
#   '9389681632',
#   'Intel Core i1-7700K',
#   datetime.date(2019, 3, 16),
#   datetime.timedelta(days=470),
#   'Yes'),
#  ('7399-9899-7082-9167',
#   'bpyjeoaid@jfyp.dxn',
#   'Kameela',
#   'el-Mahfouz',
#   '8291636325',
#   'AMD Ryzen 7 1793X',
#   datetime.date(2019, 12, 30),
#   datetime.timedelta(days=181),
#   'Yes'),
#  ('4519-8183-5798-2371',
#   'imjxtc@fehwup.ycl',
#   'Parth',
#   'Miller',
#   '6829766547',
#   'Intel Core i8-2387K',
#   datetime.date(2019, 2, 20),
#   datetime.timedelta(days=494),
#   'Yes'),
#  ('9602-3153-3284-4947',
#   'yaxeph@ckbhwlxvm.ria',
#   'Angelica',
#   'Moore',
#   '9419643621',
#   'AMD Ryzen 3 5240X',
#   datetime.date(2019, 1, 10),
#   datetime.timedelta(days=535),
#   'Yes'),
#  ('2377-5507-4417-7715',
#   'bcdsk@axymu.ojf',
#   'Jessica',
#   'Miller',
#   '2175815169',
#   'Intel Core i8-7428K',
#   datetime.date(2020, 3, 5),
#   datetime.timedelta(days=115),
#   'Yes'),
#  ('8482-2967-9180-7397',
#   'wtyci@t.rkg',
#   'Luis',
#   'al-Rahimi',
#   '4726594289',
#   'AMD Ryzen 2 3998X',
#   datetime.date(2018, 4, 2),
#   datetime.timedelta(days=818),
#   'Yes'),
#  ('7485-6663-3239-9789',
#   'tfanomvhwp@qlgkisoa.hto',
#   'Kenneth',
#   'Gordon',
#   '6936156132',
#   'Intel Core i2-1320K',
#   datetime.date(2017, 9, 13),
#   datetime.timedelta(days=1019),
#   'Yes'),
#  ('4659-7597-5011-9583',
#   'w@jhma.mec',
#   'Tamesha',
#   'Montoya',
#   '8147866952',
#   'AMD Ryzen 5 7532X',
#   datetime.date(2019, 3, 15),
#   datetime.timedelta(days=471),
#   'Yes'),
#  ('5969-1339-6191-2367',
#   'otlxiuyh@za.fbv',
#   'Elizabeth',
#   'al-Ozer',
#   '2656341782',
#   'Intel Core i5-8980K',
#   datetime.date(2017, 10, 12),
#   datetime.timedelta(days=990),
#   'Yes'),
#  ('8978-1046-2556-3624',
#   'ohik@ti.mkc',
#   'Raihaan',
#   'Beyene',
#   '3524865289',
#   'AMD Ryzen 9 8499X',
#   datetime.date(2017, 8, 20),
#   datetime.timedelta(days=1043),
#   'Yes'),
#  ('2800-6592-6010-9682',
#   'alezbfymq@xfquzioah.plk',
#   'Kelly',
#   'Althen',
#   '7456956591',
#   'Intel Core i5-6693K',
#   datetime.date(2018, 11, 18),
#   datetime.timedelta(days=588),
#   'Yes'),
#  ('1992-4588-6890-8469',
#   'tkngre@tsfyxdnv.rgf',
#   'Ashley',
#   'Hoang',
#   '8577143812',
#   'AMD Ryzen 8 2336X',
#   datetime.date(2018, 6, 26),
#   datetime.timedelta(days=733),
#   'Yes'),
#  ('1639-2423-5485-4964',
#   'wlsq@cehgz.vdu',
#   'Tayza',
#   'Nguyen',
#   '5186986745',
#   'Intel Core i3-6322K',
#   datetime.date(2018, 12, 7),
#   datetime.timedelta(days=569),
#   'Yes'),
#  ('2120-1655-6466-6040',
#   'v@sfh.iud',
#   'Brianna',
#   'Jejjoni',
#   '1495867281',
#   'AMD Ryzen 9 1829X',
#   datetime.date(2019, 5, 6),
#   datetime.timedelta(days=419),
#   'Yes'),
#  ('5526-1343-3056-3394',
#   'jxasqkle@ncfuq.tsn',
#   'Sadeeqa',
#   'Cordova',
#   '4364971687',
#   'Intel Core i7-3718K',
#   datetime.date(2019, 3, 16),
#   datetime.timedelta(days=470),
#   'Yes'),
#  ('7752-9411-8613-5132',
#   'jycvg@hpugjcar.vxn',
#   'Tyler',
#   'Vandevelde-Brown',
#   '7192471349',
#   'AMD Ryzen 1 7381X',
#   datetime.date(2018, 3, 23),
#   datetime.timedelta(days=828),
#   'Yes'),
#  ('5317-2286-8304-7667',
#   'pcwgthy@qkd.tem',
#   'Clarissa',
#   'Dorado',
#   '6921948139',
#   'Intel Core i7-3629K',
#   datetime.date(2020, 1, 28),
#   datetime.timedelta(days=152),
#   'Yes'),
#  ('3423-4368-8965-2976',
#   'hudv@swzt.uob',
#   'Rutaiba',
#   'al-Saad',
#   '8641291429',
#   'AMD Ryzen 2 1373X',
#   datetime.date(2018, 8, 8),
#   datetime.timedelta(days=690),
#   'Yes'),
#  ('9755-5822-3879-4403',
#   'ktsexfv@mxefpivrk.jeu',
#   'Corey',
#   'Gardner',
#   '9538368157',
#   'Intel Core i6-6579K',
#   datetime.date(2019, 5, 21),
#   datetime.timedelta(days=404),
#   'Yes'),
#  ('8025-7637-7894-7390',
#   'ot@svnye.kef',
#   'Reagan',
#   'Longwing',
#   '3154695164',
#   'AMD Ryzen 6 7600X',
#   datetime.date(2020, 5, 10),
#   datetime.timedelta(days=49),
#   'Yes'),
#  ('1453-7337-5108-7087',
#   'j@we.qrn',
#   'Conner',
#   'Ramirez',
#   '1423479831',
#   'Intel Core i2-6315K',
#   datetime.date(2018, 8, 26),
#   datetime.timedelta(days=672),
#   'Yes'),
#  ('8779-1499-3708-9486',
#   'vjogurab@yptmbow.qbf',
#   'Kristen',
#   'Hiser',
#   '7982614175',
#   'AMD Ryzen 6 9201X',
#   datetime.date(2019, 7, 22),
#   datetime.timedelta(days=342),
#   'Yes'),
#  ('2585-2376-7371-7994',
#   'xybj@pvm.wfx',
# ...
#   'Charles',
#   'Thorn',
#   '7868162493',
#   'AMD Ryzen 9 9346X',
#   datetime.date(2019, 11, 17),
#   datetime.timedelta(days=224),
#   'Yes'),
#  ('7410-7653-4147-3551',
#   'aeqybtpl@rblyd.aoz',
#   'Selene',
#   'Mace',
#   '6819877345',
#   'Intel Core i4-6679K',
#   datetime.date(2020, 1, 24),
#   datetime.timedelta(days=156),
#   'Yes'),
#  ('8055-3723-8302-3005',
#   'cp@wyqt.znf',
#   'Joshua',
#   'Jaggers',
#   '3858431638',
#   'AMD Ryzen 5 3293X',
#   datetime.date(2018, 2, 23),
#   datetime.timedelta(days=856),
#   'Yes'),
#  ('8635-6281-3442-6812',
#   'kwpgfjltrb@temfnsg.hzb',
#   'Sarina',
#   'Gallegos',
#   '6248372549',
#   'Intel Core i1-5372K',
#   datetime.date(2019, 5, 26),
#   datetime.timedelta(days=399),
#   'Yes'),
#  ('4403-2313-6138-4194',
#   'rfcwqjsgxh@tpvs.qba',
#   'Tyler',
#   'Smith',
#   '3615681743',
#   'AMD Ryzen 2 8524X',
#   datetime.date(2018, 6, 7),
#   datetime.timedelta(days=752),
#   'Yes'),
#  ('5701-6569-3998-5365',
#   'd@yviambqlu.zgd',
#   'Keith',
#   'Patterson',
#   '2813975231',
#   'Intel Core i9-5909K',
#   datetime.date(2018, 12, 31),
#   datetime.timedelta(days=545),
#   'Yes'),
#  ('4508-1160-3165-9039',
#   'wduh@nhsaiwg.vqi',
#   'Hope',
#   'Lofgren',
#   '6583718349',
#   'AMD Ryzen 8 6300X',
#   datetime.date(2019, 2, 6),
#   datetime.timedelta(days=508),
#   'Yes'),
#  ('2465-5142-8326-5582',
#   'gkxmfijr@xrda.fnw',
#   'Yohanes',
#   'Yachai',
#   '9833623546',
#   'Intel Core i4-8858K',
#   datetime.date(2019, 5, 16),
#   datetime.timedelta(days=409),
#   'Yes'),
#  ('6043-6720-5459-5484',
#   'bgm@ksdhve.res',
#   'Amber',
#   'Dixon Jr',
#   '1828751726',
#   'AMD Ryzen 4 2270X',
#   datetime.date(2019, 7, 25),
#   datetime.timedelta(days=339),
#   'Yes'),
#  ('4357-6578-9403-4760',
#   'mipgjvyafk@pcgbfvat.oed',
#   'Ghazaala',
#   'Rojas',
#   '7128496342',
#   'Intel Core i5-5171K',
#   datetime.date(2017, 11, 9),
#   datetime.timedelta(days=962),
#   'Yes'),
#  ('1533-9905-6615-6268',
#   'zsouxmgfl@htkmjg.mxp',
#   'Aaron',
#   'Nguyen',
#   '6525298674',
#   'AMD Ryzen 7 9755X',
#   datetime.date(2019, 3, 13),
#   datetime.timedelta(days=473),
#   'Yes'),
#  ('6985-6331-9579-9336',
#   'xzqokbg@fvy.hzs',
#   'Jatavion',
#   'Tawater',
#   '2937151462',
#   'Intel Core i8-8439K',
#   datetime.date(2019, 12, 20),
#   datetime.timedelta(days=191),
#   'Yes'),
#  ('3633-5235-3389-7407',
#   'bazgk@jrwked.mbo',
#   'Brian',
#   'Ghaffari',
#   '7542677189',
#   'AMD Ryzen 8 2429X',
#   datetime.date(2019, 8, 7),
#   datetime.timedelta(days=326),
#   'Yes'),
#  ('1415-6032-7508-1731',
#   'jqctaixpl@tlgja.iah',
#   'Aspen',
#   'Garcia',
#   '9319239684',
#   'Intel Core i5-6925K',
#   datetime.date(2017, 10, 17),
#   datetime.timedelta(days=985),
#   'Yes'),
#  ('5836-7417-7965-8735',
#   'iylexk@iap.ovt',
#   'Caitlyn',
#   'Cross',
#   '2763156249',
#   'AMD Ryzen 1 3659X',
#   datetime.date(2018, 6, 14),
#   datetime.timedelta(days=745),
#   'Yes'),
#  ('3999-1219-5622-2188',
#   'amihsxg@ljhgbvnta.tjm',
#   'Diego',
#   'al-Khalil',
#   '8573767846',
#   'Intel Core i9-5965K',
#   datetime.date(2017, 8, 26),
#   datetime.timedelta(days=1037),
#   'Yes'),
#  ('4363-6693-4734-1338',
#   'dtvbgwzoiy@kdhfe.hvb',
#   'Alan',
#   'Morales',
#   '9647414531',
#   'AMD Ryzen 4 7799X',
#   datetime.date(2017, 11, 12),
#   datetime.timedelta(days=959),
#   'Yes'),
#  ('5735-6523-9206-2181',
#   'f@nqukpamx.flz',
#   'Addison',
#   'Anderson',
#   '1481954167',
#   'Intel Core i2-1367K',
#   datetime.date(2017, 9, 5),
#   datetime.timedelta(days=1027),
#   'Yes'),
#  ('1671-8829-2377-8559',
#   'uymnicvl@ilyfb.axf',
#   'Cheyenne',
#   'Hoffman',
#   '8352858534',
#   'AMD Ryzen 1 6564X',
#   datetime.date(2018, 7, 20),
#   datetime.timedelta(days=709),
#   'Yes'),
#  ('5834-6248-9703-6929',
#   'xblni@icrplbhx.jxs',
#   'Andrew',
#   'el-Zia',
#   '3719466321',
#   'Intel Core i1-5764K',
#   datetime.date(2018, 6, 15),
#   datetime.timedelta(days=744),
#   'Yes'),
#  ('8034-4922-5643-8216',
#   'aognmlpx@snbpuwzq.ahm',
#   'Dominic',
#   'Pham',
#   '2181942158',
#   'AMD Ryzen 2 1967X',
#   datetime.date(2018, 8, 1),
#   datetime.timedelta(days=697),
#   'Yes'),
#  ('2648-7926-5050-9675',
#   'uao@jbscfpv.mib',
#   'Muntaha',
#   'Directo',
#   '6455817692',
#   'Intel Core i9-3805K',
#   datetime.date(2020, 5, 18),
#   datetime.timedelta(days=41),
#   'Yes'),
#  ('6002-8957-2583-2869',
#   'vgpkhzx@hn.qkj',
#   'Yeni',
#   'Hiraoka',
#   '2156319421',
#   'AMD Ryzen 2 8517X',
#   datetime.date(2018, 11, 7),
#   datetime.timedelta(days=599),
#   'Yes'),
#  ('8449-5214-4567-6812',
#   'lf@dkbwgocpv.jno',
#   'Jared',
#   'Wang',
#   '6749272973',
#   'Intel Core i8-3239K',
#   datetime.date(2018, 8, 14),
#   datetime.timedelta(days=684),
#   'Yes'),
#  ('6177-2559-1650-3965',
#   'el@xwfhgda.xfs',
#   'Karen',
#   'Mccleskey',
#   '2838342461',
#   'AMD Ryzen 5 1559X',
#   datetime.date(2019, 9, 5),
#   datetime.timedelta(days=297),
#   'Yes'),
#  ('4945-7260-4368-5742',
#   'utcoxs@fjtispa.iqa',
#   'Rick',
#   'Fresquez',
#   '9148923214',
#   'Intel Core i9-1971K',
#   datetime.date(2018, 12, 19),
#   datetime.timedelta(days=557),
#   'Yes'),
#  ('9714-1500-3821-9713',
#   'bltkojzfv@qjhrvztfwp.rlh',
#   'Nicolette',
#   'Maiden',
#   '3154313791',
#   'AMD Ryzen 7 5352X',
#   datetime.date(2017, 12, 23),
#   datetime.timedelta(days=918),
#   'Yes'),
#  ('6982-6636-2293-6359',
#   'dbown@w.oxn',
#   'Lauren',
#   'Ho',
#   '5978757412',
#   'Intel Core i2-2439K',
#   datetime.date(2018, 11, 22),
#   datetime.timedelta(days=584),
#   'Yes'),
#  ('1519-9268-1049-4484',
#   'yzavgie@qvojztw.zvn',
#   'Sean',
#   'Contreras',
#   '3597163815',
#   'AMD Ryzen 7 2338X',
#   datetime.date(2019, 10, 24),
#   datetime.timedelta(days=248),
#   'Yes'),
#  ('8170-8477-1042-3899',
#   'rexi@eitlpqv.pce',
#   'Anthony',
#   'Green',
#   '8362748419',
#   'Intel Core i6-8437K',
#   datetime.date(2020, 2, 12),
#   datetime.timedelta(days=137),
#   'Yes'),
#  ('8711-4800-4907-9084',
#   'icbfdyt@qaus.gij',
#   'Ashley',
#   'Hanley',
#   '6537643786',
#   'AMD Ryzen 5 4513X',
#   datetime.date(2017, 12, 12),
#   datetime.timedelta(days=929),
#   'Yes'),
#  ('6918-7353-6426-8919',
#   'xukcfoeny@v.mkq',
#   'Briana',
#   'Reich',
#   '1592497846',
#   'Intel Core i3-4442K',
#   datetime.date(2020, 5, 19),
#   datetime.timedelta(days=40),
#   'Yes'),
#  ('3483-3342-4676-8601',
#   'qzi@sfoax.blq',
#   'Taylor',
#   'Juarez',
#   '6954633245',
#   'AMD Ryzen 4 2372X',
#   datetime.date(2017, 9, 15),
#   datetime.timedelta(days=1017),
#   'Yes'),
#  ('5322-2163-4165-9145',
#   'q@wle.zdx',
#   'Amy',
#   'Richardson',
#   '7299751397',
#   'Intel Core i5-4275K',
#   datetime.date(2017, 6, 17),
#   datetime.timedelta(days=1107),
#   'Yes'),
#  ('3929-1702-5794-9652',
#   'kofshc@cquxn.zxn',
#   'Deion',
#   'Holm',
#   '4758758462',
#   'AMD Ryzen 4 4304X',
#   datetime.date(2019, 4, 26),
#   datetime.timedelta(days=429),
#   'Yes'),
#  ('6639-7906-2887-1072',
#   'wiaq@bfiph.kmy',
#   "Mas'ooda",
#   'Anderson',
#   '1527816438',
#   'Intel Core i4-2782K',
#   datetime.date(2020, 2, 25),
#   datetime.timedelta(days=124),
#   'Yes'),
#  ('1192-7582-7953-9407',
#   'tfhdluknxa@ilgwhbpkju.xgd',
#   'Manaal',
#   'el-Mansouri',
#   '6438171956',
#   'AMD Ryzen 4 1850X',
#   datetime.date(2017, 11, 26),
#   datetime.timedelta(days=945),
#   'Yes'),
#  ('9576-7544-9062-6702',
#   'somqlxznkp@pyik.qio',
#   'Marcus',
#   'Osborne',
#   '9714214156',
#   'Intel Core i4-3794K',
#   datetime.date(2019, 2, 12),
#   datetime.timedelta(days=502),
#   'Yes'),
#  ('1417-3922-4807-2239',
#   'pejrdfaw@o.xno',
#   'Faseeha',
#   'Hoang',
#   '4572487982',
#   'AMD Ryzen 4 8580X',
#   datetime.date(2020, 1, 5),
#   datetime.timedelta(days=175),
#   'Yes'),
#  ('6135-4988-3312-1275',
#   'zwx@k.hsl',
#   'Calvin',
#   'Spears',
#   '8256427689',
#   'Intel Core i1-3732K',
#   datetime.date(2020, 1, 13),
#   datetime.timedelta(days=167),
#   'Yes'),
#  ('3471-5070-1083-6782',
#   'yn@znhtrfyos.vhf',
#   'David',
#   'Williams',
#   '4192364573',
#   'AMD Ryzen 7 6251X',
#   datetime.date(2017, 7, 1),
#   datetime.timedelta(days=1093),
#   'Yes'),
#  ('8339-8899-4268-7735',
#   'kovbmp@vrsgkwauo.lxq',
#   'Warda',
#   'el-Baksh',
#   '8461728297',
#   'Intel Core i9-3767K',
#   datetime.date(2018, 2, 4),
#   datetime.timedelta(days=875),
#   'Yes'),
#  ('8484-8999-3067-4850',
#   'dfp@jzugxt.mhk',
#   'Devin',
#   'Dowd',
#   '2785672643',
#   'AMD Ryzen 4 2904X',
#   datetime.date(2019, 12, 9),
#   datetime.timedelta(days=202),
#   'Yes'),
#  ('3030-6887-4421-2212',
#   'd@u.cxu',
#   'Krishawnda',
#   'Quezada-Tena',
#   '6787156124',
#   'Intel Core i2-2731K',
#   datetime.date(2017, 12, 24),
#   datetime.timedelta(days=917),
#   'Yes'),
#  ('7483-8800-3650-1288',
#   'lev@jsgnlyftd.dnv',
#   'Grace',
#   'el-Popal',
#   '7823572163',
#   'AMD Ryzen 8 1198X',
#   datetime.date(2019, 2, 19),
#   datetime.timedelta(days=495),
#   'Yes'),
#  ('8283-2567-4008-3125',
#   'cxk@hp.mgo',
#   'Rachel',
#   'Rupp',
#   '7132174819',
#   'Intel Core i2-1609K',
#   datetime.date(2018, 6, 7),
#   datetime.timedelta(days=752),
#   'Yes'),
#  ('7322-9528-4093-4494',
#   'bjkm@naeglfvsp.amg',
#   'Jacobo',
#   'Grady',
#   '9278456312',
#   'AMD Ryzen 5 1333X',
#   datetime.date(2019, 6, 4),
#   datetime.timedelta(days=390),
#   'Yes'),
#  ('1873-6067-4276-7265',
#   'es@shnumawzjt.zvx',
#   'Hamdaan',
#   'Jones',
#   '5492382816',
#   'Intel Core i1-7616K',
#   datetime.date(2019, 5, 13),
#   datetime.timedelta(days=412),
#   'Yes'),
#  ('7257-7564-1658-7653',
#   'cfw@hktsmilx.rbs',
#   'Faarooq',
#   'Zavala',
#   '7139787524',
#   'AMD Ryzen 9 5338X',
#   datetime.date(2017, 9, 6),
#   datetime.timedelta(days=1026),
#   'Yes'),
#  ('5549-1285-7219-1713',
#   'ev@abfguki.dzu',
#   'Safar',
#   'Manley',
#   '7987532437',
#   'Intel Core i9-5914K',
#   datetime.date(2018, 2, 17),
#   datetime.timedelta(days=862),
#   'Yes'),
#  ('3130-1679-5583-9203',
#   'xh@euywohgm.sga',
#   'Jeffrey',
#   'Kasvin',
#   '2692687469',
#   'AMD Ryzen 9 3643X',
#   datetime.date(2017, 9, 25),
#   datetime.timedelta(days=1007),
#   'Yes'),
#  ('2096-1481-8746-9366',
#   'btlf@m.phi',
#   'Tin',
#   'Courkamp',
#   '7649319215',
#   'Intel Core i1-6967K',
#   datetime.date(2018, 11, 10),
#   datetime.timedelta(days=596),
#   'Yes'),
#  ('8253-9665-4158-3850',
#   'gaqkfewnd@yiowlshtc.ohj',
#   'Brittany',
#   'Gloyd',
#   '3258464139',
#   'AMD Ryzen 7 6356X',
#   datetime.date(2020, 2, 28),
#   datetime.timedelta(days=121),
#   'Yes'),
#  ('1035-8988-8315-5669',
#   'bsqx@qknxlhdofi.kci',
#   'Najlaa',
#   'Demeke',
#   '3454363576',
#   'Intel Core i3-6882K',
#   datetime.date(2020, 3, 11),
#   datetime.timedelta(days=109),
#   'Yes'),
#  ('5600-9944-4369-5928',
#   'xv@zligcje.cme',
#   'Ashlee',
#   'Percell',
#   '6126185937',
#   'AMD Ryzen 7 9757X',
#   datetime.date(2018, 7, 19),
#   datetime.timedelta(days=710),
#   'Yes'),
#  ('5939-9860-9104-3986',
#   'ebzmxdyq@vuzfdcrlb.lmb',
#   'Brooke',
#   'Landy',
#   '7347833297',
#   'Intel Core i2-1526K',
#   datetime.date(2018, 1, 21),
#   datetime.timedelta(days=889),
#   'Yes'),
#  ('6206-1279-1941-6051',
#   'fhsdqguti@gphqk.res',
#   'Uqbah',
#   'Martinez-Delariva',
#   '5979756247',
#   'AMD Ryzen 6 7355X',
#   datetime.date(2020, 2, 13),
#   datetime.timedelta(days=136),
#   'Yes'),
#  ('5596-4771-5491-2474',
#   'jao@mfwdkceju.opq',
#   'Anastacio',
#   'el-Shaer',
#   '2471782548',
#   'Intel Core i4-5937K',
#   datetime.date(2017, 8, 23),
#   datetime.timedelta(days=1040),
#   'Yes'),
#  ('4817-7846-5490-6807',
#   'qu@tjlwhqdxrg.oaj',
#   'Daniel',
#   'Sosenginh',
#   '2742379587',
#   'AMD Ryzen 4 2547X',
#   datetime.date(2019, 4, 13),
#   datetime.timedelta(days=442),
#   'Yes'),
#  ('9747-7744-4416-5604',
#   'yrsquvg@ixda.zci',
#   'Thanaa',
#   'el-Salloum',
#   '3878274813',
#   'Intel Core i1-3101K',
#   datetime.date(2020, 5, 23),
#   datetime.timedelta(days=36),
#   'Yes'),
#  ('4708-4043-9038-6226',
#   'enzprlshy@cblpdzhnf.xik',
#   'Bryce',
#   'Quinton',
#   '3187135841',
#   'AMD Ryzen 6 1533X',
#   datetime.date(2019, 8, 12),
#   datetime.timedelta(days=321),
#   'Yes'),
#  ('2044-2080-4833-8402',
#   'b@hrg.dpq',
#   'Ashlyn',
#   'Castro',
#   '1722193597',
#   'Intel Core i1-4906K',
#   datetime.date(2017, 7, 30),
#   datetime.timedelta(days=1064),
#   'Yes'),
#  ('3319-7437-8135-1940',
#   'fgu@xfcsq.wac',
#   'Adham',
#   'Mosley',
#   '4732876158',
#   'AMD Ryzen 1 1702X',
#   datetime.date(2020, 3, 16),
#   datetime.timedelta(days=104),
#   'Yes'),
#  ('1934-4451-1238-2238',
#   'cvgwq@nxzksorcql.adi',
#   'Dacia',
#   'Rodriguez',
#   '3741979563',
#   'Intel Core i4-7344K',
#   datetime.date(2017, 8, 18),
#   datetime.timedelta(days=1045),
#   'Yes'),
#  ('1244-3815-5186-4227',
#   'vxhlcmqsiz@gxmrp.ghw',
#   'Erin',
#   'Mortel',
#   '6873461248',
#   'AMD Ryzen 3 9474X',
#   datetime.date(2017, 7, 17),
#   datetime.timedelta(days=1077),
#   'Yes'),
#  ('6191-5270-5274-5262',
#   'qu@ofmklact.sor',
#   'Anddi',
#   'Johnson',
#   '8461688574',
#   'Intel Core i1-9857K',
#   datetime.date(2019, 4, 6),
#   datetime.timedelta(days=449),
#   'Yes'),
#  ('3677-7436-9606-5836',
#   'aedwglh@hmqfl.lxd',
#   "De'Moni",
#   'al-Rad',
#   '4319249876',
#   'AMD Ryzen 9 4671X',
#   datetime.date(2019, 8, 29),
#   datetime.timedelta(days=304),
#   'Yes'),
#  ('9694-4357-5023-8714',
#   'harbgisc@uoqrdiefs.qls',
#   'Jubair',
#   'al-Shaker',
#   '4163481623',
#   'Intel Core i8-1898K',
#   datetime.date(2019, 2, 23),
#   datetime.timedelta(days=491),
#   'Yes'),
#  ('5545-1670-7124-3464',
#   'tv@bo.sdl',
#   'Warren',
#   'Kitsmiller',
#   '7611421974',
#   'AMD Ryzen 2 6341X',
#   datetime.date(2019, 9, 28),
#   datetime.timedelta(days=274),
#   'Yes'),
#  ('3513-7827-5155-4138',
#   'zxcfrsgi@wo.qbi',
#   'Cerake',
#   'al-Azimi',
#   '9488246217',
#   'Intel Core i9-2864K',
#   datetime.date(2019, 9, 5),
#   datetime.timedelta(days=297),
#   'Yes'),
#  ('9625-6437-8757-7563',
#   'rizg@ezfkowlim.kjw',
#   'Taylor',
#   'George',
#   '8737621562',
#   'AMD Ryzen 4 3926X',
#   datetime.date(2018, 9, 21),
#   datetime.timedelta(days=646),
#   'Yes'),
#  ('1229-1164-3381-6939',
#   'e@qmbijav.ynk',
#   'Luis',
#   'Digby',
#   '2767493276',
#   'Intel Core i6-6557K',
#   datetime.date(2019, 12, 17),
#   datetime.timedelta(days=194),
#   'Yes'),
#  ('1874-3085-4726-6955',
#   'ztrwvc@dkj.hlo',
#   'Franco',
#   'Crowghost',
#   '7653568172',
#   'AMD Ryzen 8 4804X',
#   datetime.date(2019, 11, 9),
#   datetime.timedelta(days=232),
#   'Yes'),
#  ('3059-6633-6813-1650',
#   'lk@qijgdsuo.djt',
#   'Valeria',
#   'Isom',
#   '8758652458',
#   'Intel Core i4-6743K',
#   datetime.date(2020, 4, 19),
#   datetime.timedelta(days=70),
#   'Yes'),
#  ('6074-1396-6465-2504',
#   'hawpl@kvmorl.zju',
#   'Mawdood',
#   'Bell',
#   '2965177485',
#   'AMD Ryzen 7 5866X',
#   datetime.date(2018, 12, 8),
#   datetime.timedelta(days=568),
#   'Yes'),
#  ('6632-3994-4370-4929',
#   'kemaxlgis@rco.dcb',
#   'Cinoi',
#   'Deere',
#   '2956973759',
#   'Intel Core i5-7109K',
#   datetime.date(2018, 8, 23),
#   datetime.timedelta(days=675),
#   'Yes'),
#  ('6979-3347-2306-2597',
#   'l@kfxhrevs.iwv',
#   'Gabrielle',
#   'el-Moghaddam',
#   '7657247634',
#   'AMD Ryzen 6 3381X',
#   datetime.date(2019, 12, 2),
#   datetime.timedelta(days=209),
#   'Yes'),
#  ('3044-9748-5855-7834',
#   'onptasmdzu@ytagvbe.hcu',
#   'Vchuefeu',
#   'Fimbres',
#   '8413294192',
#   'Intel Core i2-4307K',
#   datetime.date(2017, 12, 23),
#   datetime.timedelta(days=918),
#   'Yes'),
#  ('4007-4380-8312-2954',
#   'hamxgirl@s.lrh',
#   'Melinda',
#   'Estala',
#   '4859858325',
#   'AMD Ryzen 5 5294X',
#   datetime.date(2019, 5, 18),
#   datetime.timedelta(days=407),
#   'Yes'),
#  ('5597-4259-9929-3289',
#   'xudgo@uzs.hcj',
#   'Raul',
#   'Ho',
#   '8797539578',
#   'Intel Core i2-1606K',
#   datetime.date(2018, 10, 25),
#   datetime.timedelta(days=612),
#   'Yes'),
#  ('7685-4964-5816-1264',
#   'h@jxowuqnve.cqv',
#   'Gaochazhong',
#   'el-Khalaf',
#   '9261738923',
#   'AMD Ryzen 5 8463X',
#   datetime.date(2018, 12, 2),
#   datetime.timedelta(days=574),
#   'Yes'),
#  ('8530-9720-1223-6842',
#   'fatlqojgnp@ldkabmf.xch',
#   'Connor',
#   'Castillo',
#   '3247898419',
#   'Intel Core i6-4353K',
#   datetime.date(2017, 9, 12),
#   datetime.timedelta(days=1020),
#   'Yes'),
#  ('7789-3655-8547-2536',
#   'b@zqrjtm.jbk',
#   'Kiesha',
#   'Ward',
#   '1481234158',
#   'AMD Ryzen 1 7426X',
#   datetime.date(2018, 7, 5),
#   datetime.timedelta(days=724),
#   'Yes'),
#  ('7272-5144-9722-9412',
#   'x@egpuadontc.fjb',
#   'Gregory',
#   'Pope',
#   '7417188231',
#   'Intel Core i1-6126K',
#   datetime.date(2020, 5, 26),
#   datetime.timedelta(days=33),
#   'Yes'),
#  ('4933-7519-7908-5270',
#   'txbfals@oytharejlp.xsw',
#   'Jacob',
#   'Tran',
#   '1877622197',
#   'AMD Ryzen 4 3947X',
#   datetime.date(2018, 8, 24),
#   datetime.timedelta(days=674),
#   'Yes'),
#  ('8333-9128-2573-1197',
#   'jsnckvhf@wkhteq.vsc',
#   'Raabiya',
#   'Ricks',
#   '6235949562',
#   'Intel Core i4-7406K',
#   datetime.date(2020, 3, 5),
#   datetime.timedelta(days=115),
#   'Yes'),
#  ('6360-5652-6444-3852',
#   'rnmefsp@suviaqog.tnq',
#   'Adrian',
#   'Swearnger',
#   '6957385781',
#   'AMD Ryzen 8 6660X',
#   datetime.date(2018, 11, 19),
#   datetime.timedelta(days=587),
#   'Yes'),
#  ...]

# %%
# cur.execute("select * from ppl_cpu_purchases extract(day from purchase_date::date) < 180 limit 3")

cur.execute('select version()')
cur.fetchall()
# Out:
# [('PostgreSQL 12.2 on x86_64-apple-darwin17.7.0, compiled by Apple LLVM version 10.0.0 (clang-1000.11.45.5), 64-bit',)]

# %% [markdown]
# # Create Query:
# + **By Date Range (Month & Year) of CPU's Sold**
#
# *Assume you had to find the monthly sales of cpu*

# %%
cpu_g="SELECT pg_catalog.date(date_trunc('month',purchase_date)) AS txn_month, \
count(cpu) as monthly_sum \
FROM ppl_cpu_purchases GROUP BY txn_month ORDER BY txn_month DESC"

cur.execute(cpu_g)
pd.DataFrame(cur.fetchall(),columns=['Month_yr','Items Sold']).head(7)
# Out:
#      Month_yr  Items Sold
# 0  2020-05-01         163
# 1  2020-04-01         152
# 2  2020-03-01         150
# 3  2020-02-01         157
# 4  2020-01-01         139
# 5  2019-12-01         185
# 6  2019-11-01         152

# %% [markdown]
# # THROW a <font color=red>Like</font>
# # <font color=red>SUBscribe</font> & Turn ON Notification 🔔 Bell

# %% [markdown]
# # Citations & Help:
#
# https://www.tutorialspoint.com/postgresql/postgresql_views.htm
#
# https://www.postgresqltutorial.com/managing-postgresql-views/
#
# https://www.datacamp.com/community/tutorials/materialized-views-postgresql
#
# https://www.tutorialspoint.com/postgresql/postgresql_date_time.htm
#
# https://stackoverflow.com/questions/45487731/postgres-get-number-of-days-since-date
#
# https://www.sqlservertutorial.net/sql-server-date-functions/sql-server-datediff-function/
#
# https://www.plus2net.com/sql_tutorial/date-lastweek.php
#
# https://www.postgresqltutorial.com/postgresql-case/
#
# https://stackoverflow.com/questions/17492167/group-query-results-by-month-and-year-in-postgresql
#
# https://stackoverflow.com/questions/6133107/extract-date-yyyy-mm-dd-from-a-timestamp-in-postgresql
#
# https://w3resource.com/PostgreSQL/pl-pgsql-control-structures.php
